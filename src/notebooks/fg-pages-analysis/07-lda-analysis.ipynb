# %% [markdown]
# # spaCy

# %%
import spacy
import pandas as pd
import itertools as it

# %%
nlp = spacy.load('es_core_news_lg')

# %% [markdown]
# # Phrase modelling

# %%
import codecs
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence
# Out:
# c:\Users\eduardo.moreno\AppData\Local\anaconda3\envs\env_nlp\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
def line_review(filename):
    """
    generator function to read in reviews from the file
    and un-escape the original line breaks in the text
    """
    
    with codecs.open(filename, encoding='utf_8') as f:
        for review in f:
            yield review.replace('\\n', '\n')

# %% [markdown]
# ## Unigrams

# %%
df = pd.read_pickle(r"..\..\..\data\preprocessed\clean_stemm_lemm_stop_words_fb_pages_uniques.pkl")

# %%
df.head()
# Out:
#        Facebook Id             Post Created Total Interactions  Likes  \
# 0      97984508920  2014-12-31 23:29:00 CST                 13      9
# 1  100050454251406  2014-12-31 22:09:49 CST                 44     38
# 2  100064702265343  2014-12-31 18:56:14 CST                  7      3
# 3     135613897055  2014-12-31 18:00:17 CST                 43     37
# 4  260339100808879  2014-12-31 17:33:59 CST                  0      0
#
#    Comments  Shares  Love  Wow  Haha  Sad  Angry  Care  \
# 0         2       2     0    0     0    0      0     0
# 1         0       6     0    0     0    0      0     0
# 2         1       3     0    0     0    0      0     0
# 3         0       6     0    0     0    0      0     0
# 4         0       0     0    0     0    0      0     0
#
#                                       Message_stpWrd  \
# 0   Energía #nuclear clave solución cambio climático
# 1  cambio climático debería generar atención camb...
# 2                                         REVOLUCIÓN
# 3  Percy Grandez, especialista Derecho Ambiental,...
# 4  sexta cobertura original coral permanece Carib...
#
#                                 Message_clean_stpWrd  \
# 0    energia nuclear clave solucion cambio climatico
# 1  cambio climatico deberia generar atencion camb...
# 2                                         revolucion
# 3  percy grandez especialista derecho ambiental a...
# 4  sexta cobertura original coral permanece carib...
#
#                           Message_clean_stemm_stpWrd  \
# 0         energi nucl clav par solucion cambi climat
# 1  cambi climat deberi gener mism atencion cambi ...
# 2                                  nosotr revolucion
# 3  percy grandez especial derech ambiental analiz...
# 4  sol sext part cobertur original coral permanec...
#
#                            Message_clean_lemm_stpWrd
# 0    energia nuclear clave solucion cambio climatico
# 1  cambio climatico deberio generar atencion camb...
# 2                                         revolucion
# 3  percy grandez especialista derecho ambiental a...
# 4  sexto cobertura original coral permanecer cari...

# %%
file_lemmatized_text = r'..\..\..\data\ngrams\fb-pages\lemmatized_text.txt'

if 1 == 1:
    with open(file_lemmatized_text, "w") as file:
        for item in df['Message_clean_lemm_stpWrd'].values.tolist():
            file.write(item + "\n")

# %%
unigram_sentences = LineSentence(file_lemmatized_text)

# %%
for unigram_sentence in it.islice(unigram_sentences, 230, 240):
    print(' '.join(unigram_sentence))
    print('')
# Out:
# consecuencia cambio climatico incremento nivel mar mas metro oceano mundo anunciar previamente panel cambio climatico internacional estudio estadounidense desprender agregar nivel marea local inundacion metro adicional costa vulnerable
#
# calentamiento global causar estrago ayudar cuidar planeta existir apagar luz caminar mas bici cort arbol plant reciclar bolsa plastico ampliar influencia positivo detener calentamiento global compartir
#
# idea reducir tamano burbuja mas reciente campo geoingenieria barco dejar estela burbuja mas pequena cruzar mar podrio ayudar reducir impacto entrada estela dejar barco reducir calentamiento global aparecer acento acentodiario
#
# kiri arbol combatir calentamiento global
#
# suelo peligro expansion ciudad deforestacion insostenible tierra practica gestion contaminacion sobrepastoreo cambio climatico ritmo actual degradacion suelo amenazar capacidad satisfacer necesidad generacion futuro
#
# talento alcanzar cosa alcanzar genio alcanzar mas
#
# mundo preparar agenda desarrollo sostenible suceder 2015 objetivo desarrollo milenio campana lucha pobreza historia solucion problema global pobreza aumento desigualdad cambio climatico pobreza cronico grande problema salud brote ebola africa occidental lograr accion colectivo mensaje secretario general onu ban kimoon
#
# afectar cambio climatico acceso alimento basico habitante planeta
#
# desaparecer nieve apu wamanrazu nevado 5115 msnm forma aguila emprender vuelo ubicado comunidad campesino santa barbara huancavelica 40 ano atra cubierto abundante nieve ano extension mes diciembre mayo precipitacion pluvial 10 ano fecha encontrar libre nevada lejos belleza maravilla paisaje natural cordillera chonta cerro aledano palomo ambito comunidad choclococho pultocc carhuancho causa serio calentamiento global aumentar temperatura derretir capa nieve asi lluvia ausencia nube asi tala masivo bosque pastoreo afectar agricultura ganaderia especialmente altoandin fuente dra huancavelica
#
# ciencia religion unidos cambio climatico escuchar idea observadorestva carrillazo

# %% [markdown]
# ## Bigrams

# %%
# %%time
bigram_model_filepath = r'..\..\models\ngrams\fb-pages\bigram_model_all'

# this is a bit time consuming - make the if statement True
# if you want to execute modeling yourself.
if 1 == 1:
    bigram_model = Phrases(unigram_sentences, min_count=250, threshold=20)
    bigram_model.save(bigram_model_filepath)
    
# load the finished model from disk
bigram_model = Phrases.load(bigram_model_filepath)
# Out:
# CPU times: total: 1min 9s
# Wall time: 1min 9s

# %%
# %%time
# this is a bit time consuming - make the if statement True
# if you want to execute data prep yourself.

bigram_sentences_filepath = r'..\..\..\data\ngrams\fb-pages\bigram_sentences_all.txt'

if 1 == 1:
    with codecs.open(bigram_sentences_filepath, 'w', encoding='utf_8') as f:
        for unigram_sentence in unigram_sentences:
            bigram_sentence = u' '.join(bigram_model[unigram_sentence])
            f.write(bigram_sentence + '\n')
# Out:
# CPU times: total: 1min 21s
# Wall time: 1min 21s

# %%
bigram_sentences = LineSentence(bigram_sentences_filepath)

# %%
for bigram_sentence in it.islice(bigram_sentences, 230, 240):
    print(' '.join(bigram_sentence))
    print('')
# Out:
# consecuencia cambio climatico incremento nivel_mar mas metro oceano mundo anunciar previamente panel cambio climatico internacional estudio estadounidense desprender agregar nivel marea local inundacion metro adicional costa vulnerable
#
# calentamiento_global causar_estrago ayudar cuidar planeta existir apagar_luz caminar mas bici cort arbol plant reciclar bolsa_plastico ampliar influencia positivo detener calentamiento_global compartir
#
# idea reducir tamano burbuja mas reciente campo geoingenieria barco dejar estela burbuja mas pequena cruzar mar podrio ayudar reducir impacto entrada estela dejar barco reducir calentamiento_global aparecer acento acentodiario
#
# kiri arbol combatir calentamiento_global
#
# suelo peligro expansion ciudad deforestacion insostenible tierra practica gestion contaminacion sobrepastoreo cambio climatico ritmo actual degradacion_suelo amenazar capacidad satisfacer_necesidad generacion futuro
#
# talento alcanzar cosa alcanzar genio alcanzar mas
#
# mundo preparar agenda desarrollo_sostenible suceder 2015 objetivo desarrollo milenio campana lucha pobreza historia solucion problema global pobreza aumento desigualdad cambio climatico pobreza cronico grande problema salud brote ebola africa occidental lograr accion colectivo mensaje secretario_general onu_ban kimoon
#
# afectar cambio climatico acceso alimento basico habitante planeta
#
# desaparecer nieve apu wamanrazu nevado 5115 msnm forma aguila emprender vuelo ubicado comunidad campesino santa_barbara huancavelica 40 ano atra cubierto abundante nieve ano extension mes diciembre mayo precipitacion_pluvial 10 ano fecha encontrar libre nevada lejos belleza maravilla paisaje natural cordillera chonta cerro aledano palomo ambito comunidad choclococho pultocc carhuancho causa serio calentamiento_global aumentar temperatura derretir capa nieve asi lluvia ausencia nube asi tala masivo bosque pastoreo afectar agricultura_ganaderia especialmente altoandin fuente dra huancavelica
#
# ciencia religion unidos cambio climatico escuchar idea observadorestva carrillazo

# %% [markdown]
# ## Trigrams

# %%
# %%time
# this is a bit time consuming - make the if statement True
# if you want to execute modeling yourself.
trigram_model_filepath = r'..\..\models\ngrams\fb-pages\trigram_model_all'

if 1 == 1:
    trigram_model = Phrases(bigram_sentences, min_count=200, threshold=20)
    trigram_model.save(trigram_model_filepath)
    
# load the finished model from disk
trigram_model = Phrases.load(trigram_model_filepath)
# Out:
# CPU times: total: 1min 6s
# Wall time: 1min 6s

# %%
# %%time
# this is a bit time consuming - make the if statement True
# if you want to execute data prep yourself.

trigram_sentences_filepath = r'..\..\..\data\ngrams\fb-pages\trigram_sentences_all.txt'

if 1 == 1:
    with codecs.open(trigram_sentences_filepath, 'w', encoding='utf_8') as f:
        for bigram_sentence in bigram_sentences:
            trigram_sentence = u' '.join(trigram_model[bigram_sentence])
            f.write(trigram_sentence + '\n')
# Out:
# CPU times: total: 1min 19s
# Wall time: 1min 19s

# %%
trigram_sentences = LineSentence(trigram_sentences_filepath)

# %%
for trigram_sentence in it.islice(trigram_sentences, 220, 230):
    print(' '.join(trigram_sentence))
    print('')
# Out:
# calcular presupuesto rendimiento mitigar cambio climatico mundo leelo aca
#
# atencion
#
# cientifico universidad leeds reino_unido burbuja mas chica reflejar cantidad luz_solar espacio asi limitar cantidad calor absorber oceano fuente bbccouk
#
# llegar madre ciudad
#
# agrobanco fondo verde venir diverso mecanismo orientado lograr certificacion internacional permitir captar fondo verde entidad bilateral multilateral destinado financiar proyecto orientado mitigacion cambio climatico promover asistencia_tecnico capacitacion productor pronto suscribira convenio cooperacion agencia_frances desarrollo afd cooperacion_aleman desarrollo giz implementar sistema administracion riesgo ambiental social afinar proceso impulsar financiamiento forestal sostenible sentido marco cop20 agrobanco suscribio protocolo verde comprometer promover conservacion medio_ambiente defensa biodiversidad sostenible recurso_natural renovable
#
# musical mexico llegar musica antartico ciudad mexico alejandro arzumanian
#
# contento tagers unir lucha cambio climatico ayuda empresa 100 poblana regat home invitar leer post pagina_web
#
# conducta moderado firme oposicion relaciones eeuu cuba primar conducta prudente moderado reflexivo firme virulento critica fuerza opuesto normalizacion relacion unidos sentencio general ejercito raul castro ruz presidente consejo_ministro parlamento cubano atacar mentira logro revolucion cubano secretario comite central partido_comunista cuba isla existir diverso organizacion masa sindical campesino femenino estudiantil artista gubernamental ofenderio confundir individuo recibir dinero instruccion oxigeno exterior continuar defensa paz derecho internacional causa justo asi tambien denuncia amenaza supervivencia especie humano vinculado cambio climatico arsenal nuclear asegurar raul traslado profundo gratitud revolucion pueblo partido gobierno recibir permanente solidaridad isla continuar politica_exterior base inamovible fidelidad principio especial relacion mantener republica_bolivarian venezuela contar invariable apoyo frente desestabilizar gobierno legitimo liderado presidente nicolas_maduro moro enfrentamiento ebola africa_occidental raul reitero disposicion cubano cooperar unidos ambito multi bilateral peligro requerir respuesta humanitario colectivo eficaz deber politizar declarar reciente cumbre caricom albatcp efectuado habana raul agradecio nuevamente invitacion juan_carlos varela presidente panama participar vii cumbre_america sentido general ejercito confirmar_asistencia cita previsto abril 2015 expondrir posicion cuba sinceridad respetar participacion cubano importante reunion resultado solido unanime consenso america_latino_caribe vivir epoca unir diversidad comunidad latinoamericano caribenos afirmo recordo diputado alianza bolivarian pueblo america gracias permanente reclamo apoyo pais region logro eliminacion sancion cuba establecido 1962 organizacion americano raul rememoro tambien dia cumplir 58 ano reencuentro fidel palma historica exclamacion contar fusil reiniciar lucha ganar guerra inquebrantable fe victoria inculco fidel continuar conducir pueblo defensa perfeccionamiento obra revolucion concluyo presidente consejo_ministro tomado ain
#
# calcular presupuesto rendimiento mitigar cambio climatico mundo leer aca
#
# impelable logica capital convencion_naciones_unidas cambio climatico

# %%
# %%time
# this is a bit time consuming - make the if statement True
# if you want to execute data prep yourself.

trigram_reviews_filepath = r'..\..\..\data\ngrams\fb-pages\trigram_transformed_reviews_all.txt'
trigram_reviews_filepath = trigram_sentences_filepath
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
print('Original:' + u'\n')
for review in it.islice(line_review(file_lemmatized_text), 11, 12):
    print(review)
print('----' + u'\n')
print('Transformed:' + u'\n')

with codecs.open(trigram_reviews_filepath, encoding='utf_8') as f:
    for review in it.islice(f, 11, 12):
        print(review)
# Out:
# Original:
#
# algun dia har pelicula vida mujer nominado nobel paz salvar 2500 nino premio finalmente recayo gore informe calentamiento global
#
# ----
#
# Transformed:
#
# algun dia har pelicula vida mujer nominado nobel_paz salvar 2500 nino premio finalmente recayo gore informe calentamiento_global

# %% [markdown]
# # LDA

# %%
import warnings
import multiprocessing
from gensim.corpora import Dictionary, MmCorpus
from gensim.models.ldamulticore import LdaMulticore

# %%
trigram_dictionary_filepath = r'..\..\models\ngrams\fb-pages\trigram_dict_all.dict'

# %%
# %%time

# this is a bit time consuming - make the if statement True
# if you want to learn the dictionary yourself.
if 1 == 1:

    trigram_reviews = LineSentence(trigram_reviews_filepath)

    # learn the dictionary by iterating over all of the reviews
    trigram_dictionary = Dictionary(trigram_reviews)
    
    # filter tokens that are very rare or too common from
    # the dictionary (filter_extremes) and reassign integer ids (compactify)
    trigram_dictionary.filter_extremes(no_below=300, no_above=0.4)
    trigram_dictionary.compactify()

    trigram_dictionary.save(trigram_dictionary_filepath)
    
# load the finished dictionary from disk
trigram_dictionary = Dictionary.load(trigram_dictionary_filepath)
# Out:
# CPU times: total: 46.4 s
# Wall time: 46.5 s

# %%
trigram_bow_filepath = r'..\..\models\ngrams\fb-pages\trigram_bow_corpus_all.mm'

# %%
def trigram_bow_generator(filepath):
    """
    generator function to read reviews from a file
    and yield a bag-of-words representation
    """
    
    for review in LineSentence(filepath):
        yield trigram_dictionary.doc2bow(review)

# %%
# %%time

# this is a bit time consuming - make the if statement True
# if you want to build the bag-of-words corpus yourself.
if 1 == 1:
    # generate bag-of-words representations for
    # all reviews and save them as a matrix
    MmCorpus.serialize(trigram_bow_filepath,
                       trigram_bow_generator(trigram_reviews_filepath))
# load the finished bag-of-words corpus from disk
trigram_bow_corpus = MmCorpus(trigram_bow_filepath)
# Out:
# CPU times: total: 52.8 s
# Wall time: 53.1 s

# %%
lda_model_filepath = r'..\..\models\ngrams\fb-pages\lda_model_all'

# %%
pool = multiprocessing.Pool()
num_workers = pool._processes
print(f"Number of workers in the Pool: {num_workers}")
# Out:
# Number of workers in the Pool: 16

# %%
num_topics = 50

# %%
# %%time

# this is a bit time consuming - make the if statement True
# if you want to train the LDA model yourself.
if 1 == 1:

    with warnings.catch_warnings():
        warnings.simplefilter('ignore')
        
        # workers => sets the parallelism, and should be
        # set to your number of physical cores minus one
        lda = LdaMulticore(trigram_bow_corpus,
                           num_topics=num_topics,
                           id2word=trigram_dictionary,
                           workers=num_workers,
                           )
    
    lda.save(lda_model_filepath)
    
# load the finished LDA model from disk
lda = LdaMulticore.load(lda_model_filepath)

# %% [markdown]
# ## Keywords

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud
import matplotlib.colors as mcolors

# %%
#cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'
cols = [color for name, color in mcolors.XKCD_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'
cols = cols[num_topics:num_topics*2]

cloud = WordCloud(background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(5, 2, figsize=(20,15), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
def explore_topic(topic_number, topn=25):
    """
    accept a user-supplied topic number and
    print out a formatted list of the top terms
    """
        
    print('{:20} {}'.format(u'term', u'frequency') + u'\n')

    for term, frequency in lda.show_topic(topic_number, topn=topn):
        print('{:20} {:.3f}'.format(term, round(frequency, 3)))

# %%
for topic in range(20):
    print(f"--- Topic: {topic}")
    explore_topic(topic_number=topic, topn=10)
    print("")
# Out:
# --- Topic: 0
# term                 frequency
#
# mas                  0.023
# energia              0.008
# cientifico           0.008
# ano                  0.007
# tierra               0.005
# clima                0.004
# planeta              0.004
# ciencia              0.004
# politico             0.004
# calentamiento_global 0.003
#
# --- Topic: 1
# term                 frequency
#
# cambioclimatico      0.013
# lucha                0.010
# mujer                0.010
# calentamiento_global 0.009
# mas                  0.008
# mundo                0.007
# hablar               0.007
# tema                 0.006
# internacional        0.005
# dia                  0.004
#
# --- Topic: 2
# term                 frequency
#
# mas                  0.009
# dia                  0.007
# noticia              0.007
# compartir            0.006
# agua                 0.006
# pierdar              0.005
# clima                0.004
# ano                  0.004
# hora                 0.003
# calentamiento_global 0.003
#
# --- Topic: 3
# term                 frequency
#
# ambiental            0.010
# proyecto             0.009
# mas                  0.007
# programa             0.006
# actividad            0.006
# asi                  0.004
# municipio            0.004
# medio_ambiente       0.004
# area                 0.004
# traves               0.004
#
# --- Topic: 4
# term                 frequency
#
# oceano               0.017
# agua                 0.013
# mas                  0.012
# mar                  0.010
# ecosistema           0.008
# especie              0.007
# impacto              0.007
# mundo                0.007
# afectar              0.006
# efecto               0.006
#
# --- Topic: 5
# term                 frequency
#
# mas                  0.010
# mundo                0.008
# calentamiento_global 0.007
# ano                  0.006
# ciudad               0.006
# agua                 0.006
# planeta              0.006
# tambien              0.005
# cambio               0.004
# tierra               0.003
#
# --- Topic: 6
# term                 frequency
#
# mas                  0.019
# humano               0.018
# naturaleza           0.013
# animal               0.011
# especie              0.011
# planeta              0.010
# vida                 0.010
# mundo                0.009
# tierra               0.009
# tambien              0.009
#
# --- Topic: 7
# term                 frequency
#
# mas                  0.015
# hora_planeta         0.011
# ano                  0.008
# mundo                0.007
# ciudad               0.006
# tambien              0.004
# mundial              0.003
# pais                 0.003
# jujuy                0.003
# ambiental            0.003
#
# --- Topic: 8
# term                 frequency
#
# mas                  0.008
# desarrollo           0.008
# proyecto             0.007
# nacional             0.006
# ambiental            0.005
# objetivo             0.005
# acción               0.005
# internacional        0.005
# iniciativa           0.005
# sostenible           0.005
#
# --- Topic: 9
# term                 frequency
#
# mas                  0.027
# ano                  0.010
# agua                 0.009
# calentamiento_global 0.008
# podriar              0.005
# planeta              0.005
# mundo                0.005
# zona                 0.005
# tambien              0.004
# temperatura          0.004
#
# --- Topic: 10
# term                 frequency
#
# arbol                0.021
# mas                  0.016
# dia                  0.012
# bosque               0.009
# medio_ambiente       0.008
# ciudad               0.008
# tierra               0.007
# planeta              0.007
# acción               0.007
# proteger             0.006
#
# --- Topic: 11
# term                 frequency
#
# mas                  0.019
# tierra               0.009
# ano                  0.008
# mundo                0.007
# planeta              0.006
# cientifico           0.006
# vida                 0.006
# podriar              0.005
# deber                0.005
# humano               0.005
#
# --- Topic: 12
# term                 frequency
#
# mas                  0.024
# ano                  0.018
# mundo                0.006
# país                 0.005
# tambien              0.005
# persona              0.005
# empresa              0.004
# energia              0.004
# dia                  0.003
# semana               0.003
#
# --- Topic: 13
# term                 frequency
#
# mas                  0.025
# dia                  0.014
# planeta              0.013
# mundo                0.011
# vida                 0.009
# calentamiento_global 0.008
# ano                  0.008
# tierra               0.007
# vivir                0.006
# persona              0.006
#
# --- Topic: 14
# term                 frequency
#
# '                    0.084
# mas                  0.016
# mundo                0.007
# ano                  0.006
# mujer                0.005
# agua                 0.004
# vida                 0.004
# tambien              0.004
# suelo                0.003
# tierra               0.003
#
# --- Topic: 15
# term                 frequency
#
# mas                  0.010
# and                  0.006
# the                  0.006
# mundo                0.005
# 1                    0.005
# seguir               0.004
# 3                    0.004
# 2                    0.003
# of                   0.003
# in                   0.003
#
# --- Topic: 16
# term                 frequency
#
# mas                  0.015
# mundo                0.014
# ano                  0.008
# salud                0.006
# planeta              0.006
# global               0.006
# tierra               0.006
# mundial              0.005
# vida                 0.005
# humano               0.004
#
# --- Topic: 17
# term                 frequency
#
# agua                 0.014
# mas                  0.010
# obra                 0.005
# ano                  0.005
# proyecto             0.005
# dia                  0.005
# municipio            0.004
# tambien              0.004
# gobierno             0.004
# ciudad               0.004
#
# --- Topic: 18
# term                 frequency
#
# gobierno             0.012
# mas                  0.011
# pais                 0.008
# tambien              0.006
# presidente           0.006
# deber                0.005
# mexico               0.005
# ley                  0.004
# politica             0.004
# unidos               0.004
#
# --- Topic: 19
# term                 frequency
#
# mas                  0.015
# tambien              0.007
# ano                  0.007
# planeta              0.006
# dia                  0.004
# proyecto             0.004
# utilizar             0.003
# persona              0.003
# forma                0.003
# energia              0.003
