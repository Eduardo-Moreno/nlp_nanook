# %% [markdown]
# # `spaCy`
#
# `spaCy` es una librería de Python utilizada para proyectos de **Procesamiento del Lenguaje Natural** (NLP) poniendo a la disposición del programador varias técnicas utilizadas en un pipeline de NLP:
# - Tokenization
# - Normalización del texto (eliminar mayúsculas, stemming, lemmatization)
# - Part-Of-Speech tagging
# - Named Entity Recognition (NER)
#
# Para instalar `spaCy` y dependencias:
# ```
# pip install spacy
#
# pip install es-core-news-sm
# ```

# %% [markdown]
# # Load data

# %%
import pandas as pd

# %%
df = pd.read_pickle(r"..\..\..\data\preprocessed\clean_stemm_lemm_stop_words_fb_pages_uniques.pkl")

# %%
df.columns
# Out:
# Index(['Facebook Id', 'Post Created', 'Total Interactions', 'Likes',
#        'Comments', 'Shares', 'Love', 'Wow', 'Haha', 'Sad', 'Angry', 'Care',
#        'Message_stpWrd', 'Message_clean_stpWrd', 'Message_clean_stemm_stpWrd',
#        'Message_clean_lemm_stpWrd'],
#       dtype='object')

# %% [markdown]
# En este notebook nos enfocaremos en obtener los n-gramas de la variable:
#
# - `Message_clean_lemm_stpWrd`

# %%
df.columns
# Out:
# Index(['Facebook Id', 'Post Created', 'Total Interactions', 'Likes',
#        'Comments', 'Shares', 'Love', 'Wow', 'Haha', 'Sad', 'Angry', 'Care',
#        'Message_stpWrd', 'Message_clean_stpWrd', 'Message_clean_stemm_stpWrd',
#        'Message_clean_lemm_stpWrd'],
#       dtype='object')

# %%
df[['Message_stpWrd', 'Message_clean_stpWrd', 
    'Message_clean_stemm_stpWrd', 'Message_clean_lemm_stpWrd']].head()
# Out:
#                                       Message_stpWrd  \
# 0   Energía #nuclear clave solución cambio climático
# 1  cambio climático debería generar atención camb...
# 2                                         REVOLUCIÓN
# 3  Percy Grandez, especialista Derecho Ambiental,...
# 4  sexta cobertura original coral permanece Carib...
#
#                                 Message_clean_stpWrd  \
# 0    energia nuclear clave solucion cambio climatico
# 1  cambio climatico deberia generar atencion camb...
# 2                                         revolucion
# 3  percy grandez especialista derecho ambiental a...
# 4  sexta cobertura original coral permanece carib...
#
#                           Message_clean_stemm_stpWrd  \
# 0         energi nucl clav par solucion cambi climat
# 1  cambi climat deberi gener mism atencion cambi ...
# 2                                  nosotr revolucion
# 3  percy grandez especial derech ambiental analiz...
# 4  sol sext part cobertur original coral permanec...
#
#                            Message_clean_lemm_stpWrd
# 0    energia nuclear clave solucion cambio climatico
# 1  cambio climatico deberio generar atencion camb...
# 2                                         revolucion
# 3  percy grandez especialista derecho ambiental a...
# 4  sexto cobertura original coral permanecer cari...

# %%
df.shape
# Out:
# (953693, 16)

# %% [markdown]
# Algunos mensajes (*original*, *limpio*, *stemmatizado* y *lemmatizado*) preprocesados son:

# %%
print('ORIGINAL MESSAGE')
for i, text in enumerate(df['Message_stpWrd']):
    print(f"Post {i + 1}: {text}")
    if i == 4:
        break
print("\n")

print('CLEAN MESSAGE')
for i, text in enumerate(df['Message_clean_stpWrd']):
    print(f"Post {i + 1}: {text}")
    if i == 4:
        break
print("\n")

print('STEMMED MESSAGE')
for i, text in enumerate(df['Message_clean_stemm_stpWrd']):
    print(f"Post {i + 1}: {text}")
    if i == 4:
        break
print("\n")

print('LEMMATIZED MESSAGE')
for i, text in enumerate(df['Message_clean_lemm_stpWrd']):
    print(f"Post {i + 1}: {text}")
    if i == 4:
        break
print("\n")
# Out:
# ORIGINAL MESSAGE
# Post 1: Energía #nuclear clave solución cambio climático
# Post 2: cambio climático debería generar atención cambio dígito. #FelizAñoNuevo
# Post 3: REVOLUCIÓN
# Post 4: Percy Grandez, especialista Derecho Ambiental, analiza brevemente principales sucesos marcaron presente año materia ambiental efectos normas legales, avances minería ilegal contaminación atmosférica, realización COP 20. “Finalmente, suceso permite cerrar año optimismo realización COP 20 país. cumbre cambio climático consiguió elaborar auspicioso borrador acuerdo global (...). Además, consiguió peruanos tomen conciencia importancia merece ambiente presentes futuras generaciones”; señala.
# Post 5: sexta cobertura original coral permanece Caribe. siguen están, mayoría arrecifes coral Caribe desaparecer próximas décadas, Unión Internacional Conservación Naturaleza (UICN). caso, informe UICN. acuerdo situación tendencias arrecifes coral Caribe: 1970-2012, restauración poblaciones peces loro, protección pesca excesiva, disminucion contaminación costera formas mejorar gestión costas "ayudar arrecifes recuperen hagan resistentes impactos futuros cambio climático."
#
#
# CLEAN MESSAGE
# Post 1: energia nuclear clave solucion cambio climatico
# Post 2: cambio climatico deberia generar atencion cambio digito felizanonuevo
# Post 3: revolucion
# Post 4: percy grandez especialista derecho ambiental analiza brevemente principales sucesos marcaron presente ano materia ambiental efectos normas legales avances mineria ilegal contaminacion atmosferica realizacion cop 20 finalmente suceso permite cerrar ano optimismo realizacion cop 20 pais cumbre cambio climatico consiguio elaborar auspicioso borrador acuerdo global ademas consiguio mas peruanos tomen conciencia importancia merece ambiente presentes futuras generaciones senala
# Post 5: sexta cobertura original coral permanece caribe siguen mayoria arrecifes coral caribe desaparecer proximas decadas segun union internacional conservacion naturaleza uicn caso informe uicn acuerdo situacion tendencias arrecifes coral caribe 19702012 restauracion poblaciones peces loro proteccion pesca excesiva disminucion contaminacion costera formas mejorar gestion costas ayudar arrecifes recuperen hagan mas resistentes impactos futuros cambio climatico
#
#
# STEMMED MESSAGE
# Post 1: energi nucl clav par solucion cambi climat
# Post 2: cambi climat deberi gener mism atencion cambi digit felizanonuev
# Post 3: nosotr revolucion
# Post 4: percy grandez especial derech ambiental analiz brevement principal suces marc present ano materi ambiental com efect ciert norm legal avanc mineri ilegal contamin atmosfer realiz cop 20 final suces permit cerr ano optim realiz cop 20 nuestr pais cumbr sobr cambi climat consigui elabor auspici borrador acuerd global adem consigui mas peruan tom concienci import merec ambient par present futur gener senal
# Post 5: sol sext part cobertur original coral permanec carib cos sig com mayori arrecif coral carib podri desaparec proxim dec segun union internacional par conserv naturalez uicn per tien cas dic nuev inform uicn acuerd situacion tendenci arrecif coral carib 19702012 restaur poblacion pec lor proteccion pesc exces disminucion contamin coster form gestion cost pued ayud arrecif recuper hag mas resistent impact futur cambi climat
#
#
# LEMMATIZED MESSAGE
# Post 1: energia nuclear clave solucion cambio climatico
# Post 2: cambio climatico deberio generar atencion cambio digito felizanonuevo
# Post 3: revolucion
# Post 4: percy grandez especialista derecho ambiental analizar brevemente principal suceso marcar presente ano materia ambiental efecto norma legal avance mineria ilegal contaminacion atmosferico realizacion cop 20 finalmente suceso permitir cerrar ano optimismo realizacion cop 20 pais cumbre cambio climatico consiguio elaborar auspicioso borrador acuerdo global adema consiguio mas peruano tomar conciencia importancia merecer ambiente presente futuro generacion senala
# Post 5: sexto cobertura original coral permanecer caribe cosa seguir mayoria arrecif coral caribe podriar desaparecer proxima decada segun union internacional conservacion naturaleza uicn caso informe uicn acuerdo situacion tendencia arrecif coral caribe 19702012 restauracion poblacion pez loro proteccion pesca excesivo disminucion contaminacion costero forma mejorar gestion costa ayudar arrecif recuperar mas resistente impacto futuro cambio climatico

# %% [markdown]
# # Preprocess data: Tokenize lemmatized text

# %%
from tqdm import tqdm

# %% [markdown]
# A continuación se van a crear los mensajes tokenizados. En este proyecto un token representa una **palabra**.

# %%
facebook_post_clean = df['Message_clean_lemm_stpWrd'].values.tolist()
facebook_post_clean[:5]
# Out:
# ['energia nuclear clave solucion cambio climatico',
#  'cambio climatico deberio generar atencion cambio digito felizanonuevo',
#  'revolucion',
#  'percy grandez especialista derecho ambiental analizar brevemente principal suceso marcar presente ano materia ambiental efecto norma legal avance mineria ilegal contaminacion atmosferico realizacion cop 20 finalmente suceso permitir cerrar ano optimismo realizacion cop 20 pais cumbre cambio climatico consiguio elaborar auspicioso borrador acuerdo global adema consiguio mas peruano tomar conciencia importancia merecer ambiente presente futuro generacion senala',
#  'sexto cobertura original coral permanecer caribe cosa seguir mayoria arrecif coral caribe podriar desaparecer proxima decada segun union internacional conservacion naturaleza uicn caso informe uicn acuerdo situacion tendencia arrecif coral caribe 19702012 restauracion poblacion pez loro proteccion pesca excesivo disminucion contaminacion costero forma mejorar gestion costa ayudar arrecif recuperar mas resistente impacto futuro cambio climatico']

# %%
# %time
tokens_spacy = []
for post in tqdm(facebook_post_clean):
    token_i = [token for token in post.split(' ')]
    tokens_spacy.append(token_i)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# 100%|██████████| 953693/953693 [00:10<00:00, 88099.26it/s]

# %% [markdown]
# Así se ven los post procesados como tokens:

# %%
for i in tokens_spacy[:5]:
    print(i)
# Out:
# ['energia', 'nuclear', 'clave', 'solucion', 'cambio', 'climatico']
# ['cambio', 'climatico', 'deberio', 'generar', 'atencion', 'cambio', 'digito', 'felizanonuevo']
# ['revolucion']
# ['percy', 'grandez', 'especialista', 'derecho', 'ambiental', 'analizar', 'brevemente', 'principal', 'suceso', 'marcar', 'presente', 'ano', 'materia', 'ambiental', 'efecto', 'norma', 'legal', 'avance', 'mineria', 'ilegal', 'contaminacion', 'atmosferico', 'realizacion', 'cop', '20', 'finalmente', 'suceso', 'permitir', 'cerrar', 'ano', 'optimismo', 'realizacion', 'cop', '20', 'pais', 'cumbre', 'cambio', 'climatico', 'consiguio', 'elaborar', 'auspicioso', 'borrador', 'acuerdo', 'global', 'adema', 'consiguio', 'mas', 'peruano', 'tomar', 'conciencia', 'importancia', 'merecer', 'ambiente', 'presente', 'futuro', 'generacion', 'senala']
# ['sexto', 'cobertura', 'original', 'coral', 'permanecer', 'caribe', 'cosa', 'seguir', 'mayoria', 'arrecif', 'coral', 'caribe', 'podriar', 'desaparecer', 'proxima', 'decada', 'segun', 'union', 'internacional', 'conservacion', 'naturaleza', 'uicn', 'caso', 'informe', 'uicn', 'acuerdo', 'situacion', 'tendencia', 'arrecif', 'coral', 'caribe', '19702012', 'restauracion', 'poblacion', 'pez', 'loro', 'proteccion', 'pesca', 'excesivo', 'disminucion', 'contaminacion', 'costero', 'forma', 'mejorar', 'gestion', 'costa', 'ayudar', 'arrecif', 'recuperar', 'mas', 'resistente', 'impacto', 'futuro', 'cambio', 'climatico']

# %% [markdown]
# # Phrase Modelling (N-gram)
#
# **Phrase Modelling** permite obtener combinaciones de tokens (palabras) que juntos representen conceptos de importancia (multi-palabras). Para ello, analizamos las palabras que aparecen en los posts de **Facebook** con el objetivo de analizar cuáles de ellas co-ocurren más frecuente de lo que podríamos esperar. Utilizamos el término *phrase* (*phrase*) bajo el supuesto de que una *frase* es el resultado de unir dos o más palabras. La fórmula que se utilizan los *phrase models* para construir una *frase* dadas $2$ palabras (tokens) $A$ y $B$ es:
#
# $
# \frac{count(AB) - count_{min}}{count(A)*count(B)} * N > threshold
# $
#
# En donde,
# - $count(A)$ es el número de veces que aparece el token $A$ en el corpus.
# - $count(B)$ es el número de veces que aparece el token $B$ en el corpus.
# - $count(AB)$ es el número de veces que co-aparecen los token $AB$ (juntos) en el corpus.
# - $N$ es el tamaño del vocabulario del corpus (palabras únicas).
# - $count_{min}$ hiperparámetro predefinido que asegura que los tokens (en este caso $AB$) co-ocurran al menos un número de veces.
# - $threshold$ hiperparámetro predefinido para controlar la "relevancia" que debe tener la co-ocurrencia de dos tokens para ser aceptada como una *frase*.
#
#
# Se crearán modelos encargados de calcular **n-gramas** (bigrama y trigrama). Para ello se utilizará versión `1.10.1` de `scipy`. La cual puede ser instalada con la siguiente línea de código:
#
# ```
# pip install scipy==1.10.1
# ```

# %%
import gensim
from collections import Counter
# Out:
# c:\Users\eduardo.moreno\AppData\Local\anaconda3\envs\env_nlp\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %% [markdown]
# ## Bigrams

# %% [markdown]
# Creación del modelo para obtener bigramas (*phrase models*)

# %%
bigram = gensim.models.Phrases(tokens_spacy, min_count=250, threshold=20)

# %% [markdown]
# Así se ven los textos convirtiendo tokens a *frases* (bigramas):

# %%
posts_bigram = bigram[tokens_spacy]
for i in posts_bigram[:10]:
    print(i)
# Out:
# ['energia', 'nuclear', 'clave', 'solucion', 'cambio', 'climatico']
# ['cambio', 'climatico', 'deberio', 'generar', 'atencion', 'cambio', 'digito', 'felizanonuevo']
# ['revolucion']
# ['percy', 'grandez', 'especialista', 'derecho', 'ambiental', 'analizar', 'brevemente', 'principal', 'suceso', 'marcar', 'presente', 'ano', 'materia', 'ambiental', 'efecto', 'norma', 'legal', 'avance', 'mineria_ilegal', 'contaminacion_atmosferico', 'realizacion', 'cop', '20', 'finalmente', 'suceso', 'permitir', 'cerrar', 'ano', 'optimismo', 'realizacion', 'cop', '20', 'pais', 'cumbre', 'cambio', 'climatico', 'consiguio', 'elaborar', 'auspicioso', 'borrador', 'acuerdo', 'global', 'adema', 'consiguio', 'mas', 'peruano', 'tomar_conciencia', 'importancia', 'merecer', 'ambiente', 'presente', 'futuro_generacion', 'senala']
# ['sexto', 'cobertura', 'original', 'coral', 'permanecer', 'caribe', 'cosa', 'seguir', 'mayoria', 'arrecif_coral', 'caribe', 'podriar_desaparecer', 'proxima_decada', 'segun', 'union', 'internacional', 'conservacion', 'naturaleza_uicn', 'caso', 'informe', 'uicn', 'acuerdo', 'situacion', 'tendencia', 'arrecif_coral', 'caribe', '19702012', 'restauracion', 'poblacion', 'pez', 'loro', 'proteccion', 'pesca', 'excesivo', 'disminucion', 'contaminacion', 'costero', 'forma', 'mejorar', 'gestion', 'costa', 'ayudar', 'arrecif', 'recuperar', 'mas', 'resistente', 'impacto', 'futuro', 'cambio', 'climatico']
# ['blog', 'planeta', 'futuro', 'hablar', 'banca', 'etico', 'mujer', 'africano', 'rol', 'ciudad', 'cambio', 'climatico', 'prediccion', 'america_latino', 'cuento', 'navidad']
# ['politica', 'religion', 'cambio', 'climatico', 'esperar', '2015']
# ['2014', 'caluroso', 'clave', 'recalentamiernto', 'resumen2014']
# ['oscuro', 'planeta', 'iluminar', 'fiesta']
# ['2015', 'llegar', 'hora', 'lucha', 'calentamiento_global', 'quedar', '12', 'mes', '195_pais', 'negociar', 'firmar', 'paris', 'acuerdo', 'mundial', 'supondriar', 'giro', 'historico', 'combate', 'calentamiento', 'climatico', '2015', 'sera', 'determinante', 'condicion', 'vida', 'nieto']

# %% [markdown]
# Ahora, procesemos todos los posts utilizando el modelo `bigram`

# %%
tokens_bigram = [item for sublist in tokens_spacy for item in bigram[sublist]]
corpus_post_model_bigram = Counter(tokens_bigram)

# %% [markdown]
# El top-20 de bigramas (*phrases*) y tokens con mayor frecuencia es:

# %%
for word, count in corpus_post_model_bigram.most_common(20):
    print(f'{word}: {count}')
# Out:
# climatico: 855091
# cambio: 847316
# mas: 464688
# ano: 218357
# pais: 183824
# agua: 149466
# dia: 145913
# mundo: 144062
# medio_ambiente: 133907
# tambien: 129384
# ambiental: 126786
# proyecto: 126433
# gobierno: 122744
# nacional: 121653
# accion: 120280
# planeta: 119793
# desarrollo: 111504
# mundial: 106425
# internacional: 99152
# asi: 98798

# %% [markdown]
# Mientras que el Top-$20$ de *bigramas* con mayor frecuencia es:

# %%
bigrams = [i for i in tokens_bigram if '_' in i]
corpus_bigrams = Counter(bigrams)

# %%
for word, count in corpus_bigrams.most_common(20):
    print(f'{word}: {count}')
# Out:
# medio_ambiente: 133907
# calentamiento_global: 96445
# desarrollo_sostenible: 33377
# recurso_natural: 28739
# naciones_unidas: 27662
# gas_efecto: 18983
# energia_renovable: 18897
# acuerdo_paris: 18408
# america_latino: 16896
# efecto_invernadero: 16183
# millon_persona: 16150
# incendio_forestal: 15894
# costa_rico: 14789
# gestion_riesgo: 13106
# emision_gas: 12651
# derechos_humanos: 12288
# reducir_emision: 12286
# ola_calor: 11978
# educacion_ambiental: 11260
# union_europea: 10832

# %% [markdown]
# ## Trigrams

# %% [markdown]
# Para el caso de trigramas, se utilizará el objeto `posts_bigram` que contiene los posts procesados en cuanto a frases y se aplicará un nuevo modelo `trigram`. Nótese que la creación de los posts lleva una **recurrencia** (se utiliza el resultado previo para el cálculo del nuevo).

# %%
trigram = gensim.models.Phrases(posts_bigram, min_count=200, threshold=20)

# %%
posts_trigram = trigram[posts_bigram]
for i in posts_trigram[:10]:
    print(i)
# Out:
# ['energia_nuclear', 'clave', 'solucion', 'cambio', 'climatico']
# ['cambio', 'climatico', 'deberio', 'generar', 'atencion', 'cambio', 'digito', 'felizanonuevo']
# ['revolucion']
# ['percy', 'grandez', 'especialista', 'derecho', 'ambiental', 'analizar', 'brevemente', 'principal', 'suceso', 'marcar', 'presente', 'ano', 'materia', 'ambiental', 'efecto', 'norma', 'legal', 'avance', 'mineria_ilegal', 'contaminacion_atmosferico', 'realizacion', 'cop_20', 'finalmente', 'suceso', 'permitir', 'cerrar', 'ano', 'optimismo', 'realizacion', 'cop_20', 'pais', 'cumbre', 'cambio', 'climatico', 'consiguio', 'elaborar', 'auspicioso', 'borrador', 'acuerdo', 'global', 'adema', 'consiguio', 'mas', 'peruano', 'tomar_conciencia', 'importancia', 'merecer', 'ambiente', 'presente', 'futuro_generacion', 'senala']
# ['sexto', 'cobertura', 'original', 'coral', 'permanecer', 'caribe', 'cosa', 'seguir', 'mayoria', 'arrecif_coral', 'caribe', 'podriar_desaparecer', 'proxima_decada', 'segun', 'union', 'internacional', 'conservacion_naturaleza_uicn', 'caso', 'informe', 'uicn', 'acuerdo', 'situacion', 'tendencia', 'arrecif_coral', 'caribe', '19702012', 'restauracion', 'poblacion', 'pez', 'loro', 'proteccion', 'pesca', 'excesivo', 'disminucion', 'contaminacion', 'costero', 'forma', 'mejorar', 'gestion', 'costa', 'ayudar', 'arrecif', 'recuperar', 'mas', 'resistente', 'impacto', 'futuro', 'cambio', 'climatico']
# ['blog', 'planeta', 'futuro', 'hablar', 'banca', 'etico', 'mujer', 'africano', 'rol', 'ciudad', 'cambio', 'climatico', 'prediccion', 'america_latino', 'cuento', 'navidad']
# ['politica', 'religion', 'cambio', 'climatico', 'esperar', '2015']
# ['2014', 'caluroso', 'clave', 'recalentamiernto', 'resumen2014']
# ['oscuro', 'planeta', 'iluminar', 'fiesta']
# ['2015', 'llegar', 'hora', 'lucha', 'calentamiento_global', 'quedar', '12', 'mes', '195_pais', 'negociar', 'firmar', 'paris', 'acuerdo', 'mundial', 'supondriar', 'giro', 'historico', 'combate', 'calentamiento', 'climatico', '2015', 'sera', 'determinante', 'condicion', 'vida', 'nieto']

# %% [markdown]
# La siguiente línea de código procesa los `posts_bigram` con el objetivo de obtener trigramas relevantes (nuevas *frases*):

# %%
tokens_trigram = [item for sublist in posts_bigram for item in trigram[sublist]]
corpus_post_model_trigram = Counter(tokens_trigram)

# %% [markdown]
# Obtengamos únicamente los trigramas:

# %%
trigrams = [i for i in tokens_trigram if i.count('_') == 2]
corpus_trigrams = Counter(trigrams)

# %% [markdown]
# El Top-$20$ de trigramas con mayor frecuencia es:

# %%
for word, count in corpus_trigrams.most_common(20):
    print(f'{word}: {count}')
# Out:
# gas_efecto_invernadero: 11840
# cuidado_medio_ambiente: 8273
# objetivo_desarrollo_sostenible: 8083
# america_latino_caribe: 6161
# conferencia_naciones_unidas: 5908
# area_natural_protegido: 5327
# organizacion_naciones_unidas: 4997
# aumento_nivel_mar: 4959
# celebrar_dia_mundial: 3617
# gestion_riesgo_desastre: 3089
# mejorar_calidad_vida: 3005
# reduccion_riesgo_desastre: 2344
# leer_nota_completo: 1972
# emision_dioxido_carbono: 1935
# mil_millon_dolar: 1928
# limitar_calentamiento_global: 1923
# celebrar_dia_internacional: 1852
# organizacion_sociedad_civil: 1823
# red_argentino_municipio: 1616
# banco_interamericano_desarrollo: 1589
