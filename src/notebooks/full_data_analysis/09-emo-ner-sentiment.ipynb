# %% [markdown]
# # Load data

# %%
import pandas as pd

# %%
df = pd.read_pickle(r"..\..\..\data\preprocessed\clean_stemm_lemm_stop_words_uniques.pkl")

# %%
df.shape

# %%
df.head()

# %%
df.columns

# %%
selected_data = df[['Message' ,'Message_stpWrd', 'Message_clean_lemm_stpWrd']]

# %%
selected_data.head()

# %% [markdown]
# # spaCy

# %% [markdown]
# We are going to use `spaCy`'s pretrained models to extract all organizations mentioned on the posts

# %%
import spacy
from spacy import displacy
from collections import Counter

# %%
spacy.__version__

# %%
nlp = spacy.load('es_core_news_lg')

# %% [markdown]
# We will use `spaCy` models to identify and extract organizations from posts:

# %%
doc = nlp(selected_data.iloc[418233]['Message'])

# %%
displacy.serve(doc, style="ent")

# %%
doc.ents

# %% [markdown]
# Generar función para extraer todas las organizaciones mencionadas en cada un post de Facebook.

# %%
def get_orgs(text):
    doc = nlp(text)
    org_list = []
    for entity in doc.ents:
        if entity.label_ == 'ORG':
            org_list.append(entity.text)
    org_list = list(set(org_list))
    return org_list

# %% [markdown]
# The next cell takes around $4$ hours to extract all organizations...

# %%
if 1 == 0:
    selected_data['organizations'] = selected_data['Message'].apply(get_orgs)
    selected_data.to_pickle(r"..\..\..\data\preprocessed\full_data_organizations.pkl")
else:
    selected_data = pd.read_pickle(r"..\..\..\data\preprocessed\full_data_organizations.pkl")
selected_data.head()

# %% [markdown]
# Let's extract all organizations:

# %%
orgs = selected_data['organizations'].to_list()
orgs = [org for sublist in orgs for org in sublist]

# %%
org_freq = Counter(orgs)
org_freq.most_common(20)

# %% [markdown]
# What about the following post?

# %%
print(selected_data.iloc[0]['Message'])

# %%
selected_data.iloc[0]['organizations']

# %% [markdown]
# # Hugging Face (*Transformers*)

# %%
from transformers import pipeline

# %%
distilled_student_sentiment_classifier = pipeline(
    model="lxyuan/distilbert-base-multilingual-cased-sentiments-student", 
    return_all_scores=True
)

# %%
distilled_student_sentiment_classifier("I love this movie and i would watch it again and again!")

# %%
print(selected_data.iloc[418233]['Message'])

# %%
distilled_student_sentiment_classifier(selected_data.iloc[418233]['Message'])

# %%
# Until here!!!
1/0

# %%
df_aux = pd.DataFrame()

list = selected_data['Message'].to_list()[:10]

# %%
list

# %%
sentiment = []
for i in list:
    sentiment.append(distilled_student_sentiment_classifier(i))

# %% [markdown]
# # References
# - [Intro to `spaCy`](https://spacy.io/usage/spacy-101/)
# - [spaCy NER](https://spacy.io/usage/linguistic-features#named-entities)
# - [spaCy visualizaition](https://spacy.io/usage/visualizers)
# - [Hugging Face model DistilBert](https://huggingface.co/lxyuan/distilbert-base-multilingual-cased-sentiments-student?)
