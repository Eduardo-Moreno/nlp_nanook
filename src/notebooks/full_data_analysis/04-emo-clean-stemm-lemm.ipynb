# %%
import pandas as pd
import spacy
import sys
sys.path.insert(0, r'C:\Users\eduardo.moreno\OneDrive - NEORIS\Desktop\courses\nlp\nlp_nanook\src') # Windows
from utils.utils import clean_text

# %%
df_stemm_lemm = pd.read_pickle(r'..\..\..\data\preprocessed\stemm_lemm_stop_words_stop.pkl')

# %%
df_stemm_lemm.columns
# Out:
# Index(['Facebook Id', 'Post Created', 'Total Interactions', 'Likes',
#        'Comments', 'Shares', 'Love', 'Wow', 'Haha', 'Sad', 'Angry', 'Care',
#        'Message', 'Message_stpWrd', 'Message_clean_stpWrd',
#        'Message_clean_stemm_stpWrd', 'Message_clean_lemm_stpWrd'],
#       dtype='object')

# %%
df_stemm_lemm.head()
# Out:
#        Facebook Id             Post Created Total Interactions  Likes  \
# 0  153630631414604  2016-01-05 20:55:17 CST              7,836   7266
# 1  344760762323803  2018-03-25 20:22:33 CST             12,530   2946
# 2  663135523805166  2018-04-26 15:23:31 CDT              3,727   2137
# 3  461295120574213  2016-05-02 17:59:04 CDT              3,146   2548
# 4  663135523805166  2016-06-28 23:41:26 CDT              2,804   2367
#
#    Comments  Shares  Love  Wow  Haha  Sad  Angry  Care  \
# 0       442      63    51    1     9    2      0     2
# 1        44    9025   357    4   112    7     17    18
# 2        77     917   583   10     2    0      1     0
# 3       249     188   123    7    28    2      1     0
# 4        57     181    87    5     3    8     96     0
#
#                                              Message  \
# 0  A LOS NACIDOS ENTRE 1970 Y 1987 Somos una gene...
# 1  PORQUE VOTARE POR GUSTAVO PETRO Hoy quiero com...
# 2  Ministra de medio ambiente, a trabajar por el ...
# 3  A LOS NACIDOS ENTRE 1970 Y 1987 Somos una gene...
# 4  AYÚDANOS A COMPARTIR LA IMAGEN.. Por tan magni...
#
#                                       Message_stpWrd  \
# 0  NACIDOS 1970 1987 generación especial denomina...
# 1  VOTARE GUSTAVO PETRO quiero compartir ustedes ...
# 2  Ministra medio ambiente, cambio climático desc...
# 3  NACIDOS 1970 1987 generación especial denomina...
# 4  AYÚDANOS COMPARTIR IMAGEN.. magnicfico POT (Pl...
#
#                                 Message_clean_stpWrd  \
# 0  nacidos 1970 1987 generacion especial denomina...
# 1  votare gustavo petro quiero compartir ustedes ...
# 2  ministra medio ambiente cambio climatico desca...
# 3  nacidos 1970 1987 generacion especial denomina...
# 4  ayudanos compartir imagen magnicfico pot plan ...
#
#                           Message_clean_stemm_stpWrd  \
# 0  nac 1970 1987 som gener especial denomin gener...
# 1  porqu votar gustav petr quier compart seguidor...
# 2  ministr medi ambient trabaj cambi climat desca...
# 3  nac 1970 1987 som gener especial denomin gener...
# 4  ayudan compart imag magnicf pot plan orden ter...
#
#                            Message_clean_lemm_stpWrd
# 0  nacido 1970 1987 generacion especial denominar...
# 1  votare gustavo petro querer compartir seguidor...
# 2  ministra medio ambiente cambio climatico desca...
# 3  nacido 1970 1987 generacion especial denominar...
# 4  ayudano compartir imagen magnicfico pot plan o...

# %%
nlp = spacy.load('es_core_news_lg')

# %%
def lematizar_texto(texto):
    lemas = nlp(texto)
    lematizado = [token.lemma_ for token in lemas]
    return ' '.join(lematizado)

# %%
df_stemm_lemm['Message_clean_lemm_stpWrd'][5]
# Out:
# %%
clean_lemm = df_stemm_lemm['Message_clean_lemm_stpWrd'].apply(lambda x: clean_text(x))
df_stemm_lemm['Message_clean_lemm_stpWrd'] = clean_lemm

# %%
df_stemm_lemm.head()
# Out:
#        Facebook Id             Post Created Total Interactions  Likes  \
# 0  153630631414604  2016-01-05 20:55:17 CST              7,836   7266
# 1  344760762323803  2018-03-25 20:22:33 CST             12,530   2946
# 2  663135523805166  2018-04-26 15:23:31 CDT              3,727   2137
# 3  461295120574213  2016-05-02 17:59:04 CDT              3,146   2548
# 4  663135523805166  2016-06-28 23:41:26 CDT              2,804   2367
#
#    Comments  Shares  Love  Wow  Haha  Sad  Angry  Care  \
# 0       442      63    51    1     9    2      0     2
# 1        44    9025   357    4   112    7     17    18
# 2        77     917   583   10     2    0      1     0
# 3       249     188   123    7    28    2      1     0
# 4        57     181    87    5     3    8     96     0
#
#                                              Message  \
# 0  A LOS NACIDOS ENTRE 1970 Y 1987 Somos una gene...
# 1  PORQUE VOTARE POR GUSTAVO PETRO Hoy quiero com...
# 2  Ministra de medio ambiente, a trabajar por el ...
# 3  A LOS NACIDOS ENTRE 1970 Y 1987 Somos una gene...
# 4  AYÚDANOS A COMPARTIR LA IMAGEN.. Por tan magni...
#
#                                       Message_stpWrd  \
# 0  NACIDOS 1970 1987 generación especial denomina...
# 1  VOTARE GUSTAVO PETRO quiero compartir ustedes ...
# 2  Ministra medio ambiente, cambio climático desc...
# 3  NACIDOS 1970 1987 generación especial denomina...
# 4  AYÚDANOS COMPARTIR IMAGEN.. magnicfico POT (Pl...
#
#                                 Message_clean_stpWrd  \
# 0  nacidos 1970 1987 generacion especial denomina...
# 1  votare gustavo petro quiero compartir ustedes ...
# 2  ministra medio ambiente cambio climatico desca...
# 3  nacidos 1970 1987 generacion especial denomina...
# 4  ayudanos compartir imagen magnicfico pot plan ...
#
#                           Message_clean_stemm_stpWrd  \
# 0  nac 1970 1987 som gener especial denomin gener...
# 1  porqu votar gustav petr quier compart seguidor...
# 2  ministr medi ambient trabaj cambi climat desca...
# 3  nac 1970 1987 som gener especial denomin gener...
# 4  ayudan compart imag magnicf pot plan orden ter...
#
#                            Message_clean_lemm_stpWrd
# 0  nacido 1970 1987 generacion especial denominar...
# 1  votare gustavo petro querer compartir seguidor...
# 2  ministra medio ambiente cambio climatico desca...
# 3  nacido 1970 1987 generacion especial denominar...
# 4  ayudano compartir imagen magnicfico pot plan o...

# %% [markdown]
# Eliminar mensajes duplicados

# %%
df_stemm_lemm.shape
# Out:
# (1392634, 17)

# %%
df_stemm_lemm.drop_duplicates(subset="Message_clean_lemm_stpWrd").shape
# Out:
# (1097515, 17)

# %% [markdown]
# Hay un total de $295,119$ repetidos, lo cual puede interpretare como "reposts" de otro mensaje.

# %%
df_stemm_lemm.to_pickle(r'..\..\..\data\preprocessed\clean_stemm_lemm_stop_words.pkl')

# %%
df_stemm_lemm.drop_duplicates(subset="Message_clean_lemm_stpWrd").to_pickle(r'..\..\..\data\preprocessed\clean_stemm_lemm_stop_words_uniques.pkl')
