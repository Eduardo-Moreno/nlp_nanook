# %% [markdown]
# # spaCy

# %%
import spacy
import pandas as pd
import itertools as it

# %%
nlp = spacy.load('es_core_news_lg')

# %% [markdown]
# # Phrase modelling

# %%
import codecs
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence
# Out:
# c:\Users\eduardo.moreno\AppData\Local\anaconda3\envs\env_nlp\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
def line_review(filename):
    """
    generator function to read in reviews from the file
    and un-escape the original line breaks in the text
    """
    
    with codecs.open(filename, encoding='utf_8') as f:
        for review in f:
            yield review.replace('\\n', '\n')

# %% [markdown]
# ## Unigrams

# %%
df = pd.read_pickle(r"..\..\..\data\preprocessed\clean_stemm_lemm_stop_words_uniques.pkl")

# %%
df.head()
# Out:
#        Facebook Id             Post Created Total Interactions  Likes  \
# 0  153630631414604  2016-01-05 20:55:17 CST              7,836   7266
# 1  344760762323803  2018-03-25 20:22:33 CST             12,530   2946
# 2  663135523805166  2018-04-26 15:23:31 CDT              3,727   2137
# 3  461295120574213  2016-05-02 17:59:04 CDT              3,146   2548
# 4  663135523805166  2016-06-28 23:41:26 CDT              2,804   2367
#
#    Comments  Shares  Love  Wow  Haha  Sad  Angry  Care  \
# 0       442      63    51    1     9    2      0     2
# 1        44    9025   357    4   112    7     17    18
# 2        77     917   583   10     2    0      1     0
# 3       249     188   123    7    28    2      1     0
# 4        57     181    87    5     3    8     96     0
#
#                                       Message_stpWrd  \
# 0  NACIDOS 1970 1987 generación especial denomina...
# 1  VOTARE GUSTAVO PETRO quiero compartir ustedes ...
# 2  Ministra medio ambiente, cambio climático desc...
# 3  NACIDOS 1970 1987 generación especial denomina...
# 4  AYÚDANOS COMPARTIR IMAGEN.. magnicfico POT (Pl...
#
#                                 Message_clean_stpWrd  \
# 0  nacidos 1970 1987 generacion especial denomina...
# 1  votare gustavo petro quiero compartir ustedes ...
# 2  ministra medio ambiente cambio climatico desca...
# 3  nacidos 1970 1987 generacion especial denomina...
# 4  ayudanos compartir imagen magnicfico pot plan ...
#
#                           Message_clean_stemm_stpWrd  \
# 0  nac 1970 1987 som gener especial denomin gener...
# 1  porqu votar gustav petr quier compart seguidor...
# 2  ministr medi ambient trabaj cambi climat desca...
# 3  nac 1970 1987 som gener especial denomin gener...
# 4  ayudan compart imag magnicf pot plan orden ter...
#
#                            Message_clean_lemm_stpWrd
# 0  nacido 1970 1987 generacion especial denominar...
# 1  votare gustavo petro querer compartir seguidor...
# 2  ministra medio ambiente cambio climatico desca...
# 3  nacido 1970 1987 generacion especial denominar...
# 4  ayudano compartir imagen magnicfico pot plan o...

# %%
file_lemmatized_text = r'..\..\..\data\ngrams\full-data\lemmatized_text.txt'

if 1 == 1:
    with open(file_lemmatized_text, "w") as file:
        for item in df['Message_clean_lemm_stpWrd'].values.tolist():
            file.write(item + "\n")

# %%
unigram_sentences = LineSentence(file_lemmatized_text)

# %%
for unigram_sentence in it.islice(unigram_sentences, 230, 240):
    print(' '.join(unigram_sentence))
    print('')
# Out:
# pasar energia limpio futuro
#
# petro populista propuesta colombia implementar politica economica social medioambiental manejar uruguay dia
#
# ministro deberar dedicar sabado replantar arbol pais
#
# asi equipar avion toxico nanoparticula geoingenierio chemtrails quimico toxico veneno cielo asi instalar quimico avion asi fumigar asi modificacion clima asi tirar quimico persona naturaleza crear mutacion modificacion traer enfermedad cosa chemtrails persona '' estela jet ignorancia '' hablar cambio climatico demas tema ciego estupidez humano
#
# arbol talar animal extinguir rio secar humanidad entendera dinero mundo doloroso colosal cerro oriental flora fauna recurso natural perecer frente esperanza persona dia dia luchar mundo culpa gobierno negligente jamas tomar represarias cambio climatico dia realidad afectar bogota afectar nacion sociedad planeta aun asi buscar acabar reserva natural ten misericordia dios perdonanos ayudar tarde seaesto todosesto alcaso depronto alcansar quedar hijo
#
# calentamiento global contaminacion asi afectar
#
# impactante desprendimiento glaciar grey patgonia chileno producto calentamiento global planeta
#
# aprovechar ocasion
#
# nevada notar cambio climatico
#
# muestra mas calentamiento global

# %% [markdown]
# ## Bigrams

# %%
# %%time
bigram_model_filepath = r'..\..\models\ngrams\full-data\bigram_model_all'

# this is a bit time consuming - make the if statement True
# if you want to execute modeling yourself.
if 1 == 1:
    bigram_model = Phrases(unigram_sentences, min_count=250, threshold=20)
    bigram_model.save(bigram_model_filepath)
    
# load the finished model from disk
bigram_model = Phrases.load(bigram_model_filepath)
# Out:
# CPU times: total: 1min 26s
# Wall time: 1min 26s

# %%
# %%time
# this is a bit time consuming - make the if statement True
# if you want to execute data prep yourself.

bigram_sentences_filepath = r'..\..\..\data\ngrams\full-data\bigram_sentences_all.txt'

if 1 == 1:
    with codecs.open(bigram_sentences_filepath, 'w', encoding='utf_8') as f:
        for unigram_sentence in unigram_sentences:
            bigram_sentence = u' '.join(bigram_model[unigram_sentence])
            f.write(bigram_sentence + '\n')
# Out:
# CPU times: total: 1min 45s
# Wall time: 1min 45s

# %%
bigram_sentences = LineSentence(bigram_sentences_filepath)

# %%
for bigram_sentence in it.islice(bigram_sentences, 230, 240):
    print(' '.join(bigram_sentence))
    print('')
# Out:
# pasar energia_limpio futuro
#
# petro populista propuesta colombia implementar politica economica social medioambiental manejar uruguay dia
#
# ministro deberar dedicar sabado replantar arbol pais
#
# asi equipar avion toxico nanoparticula geoingenierio chemtrails quimico toxico veneno cielo asi instalar quimico avion asi fumigar asi modificacion clima asi tirar quimico persona naturaleza crear mutacion modificacion traer enfermedad cosa chemtrails persona '' estela jet ignorancia '' hablar cambio climatico demas tema ciego estupidez humano
#
# arbol talar animal extinguir rio secar humanidad entendera dinero mundo doloroso colosal cerro oriental flora_fauna recurso_natural perecer frente esperanza persona dia dia luchar mundo culpa gobierno negligente jamas tomar represarias cambio climatico dia realidad afectar bogota afectar nacion sociedad planeta aun asi buscar acabar reserva natural ten misericordia dios perdonanos ayudar tarde seaesto todosesto alcaso depronto alcansar quedar hijo
#
# calentamiento_global contaminacion asi afectar
#
# impactante desprendimiento glaciar grey patgonia chileno producto calentamiento_global planeta
#
# aprovechar ocasion
#
# nevada notar cambio climatico
#
# muestra mas calentamiento_global

# %% [markdown]
# ## Trigrams

# %%
# %%time
# this is a bit time consuming - make the if statement True
# if you want to execute modeling yourself.
trigram_model_filepath = r'..\..\models\ngrams\full-data\trigram_model_all'

if 1 == 1:
    trigram_model = Phrases(bigram_sentences, min_count=200, threshold=20)
    trigram_model.save(trigram_model_filepath)
    
# load the finished model from disk
trigram_model = Phrases.load(trigram_model_filepath)
# Out:
# CPU times: total: 1min 26s
# Wall time: 1min 26s

# %%
# %%time
# this is a bit time consuming - make the if statement True
# if you want to execute data prep yourself.

trigram_sentences_filepath = r'..\..\..\data\ngrams\full-data\trigram_sentences_all.txt'

if 1 == 1:
    with codecs.open(trigram_sentences_filepath, 'w', encoding='utf_8') as f:
        for bigram_sentence in bigram_sentences:
            trigram_sentence = u' '.join(trigram_model[bigram_sentence])
            f.write(trigram_sentence + '\n')
# Out:
# CPU times: total: 1min 43s
# Wall time: 1min 43s

# %%
trigram_sentences = LineSentence(trigram_sentences_filepath)

# %%
for trigram_sentence in it.islice(trigram_sentences, 220, 230):
    print(' '.join(trigram_sentence))
    print('')
# Out:
# dia pachamama saludo cambio climatico uruguay elizabeth gomez
#
# inteligencia
#
# habrir paz considerar cambio climatico adaptacion variable construccion pais
#
# opinar
#
# 12 minuto experto desmentir dato argumento solido hampon neoliberal penalosir mentira reserva der hammen destruir reserva der hammen aumentario efecto cambio climatico ciudad destruir reserva condenar nieto tapaboca salir_calle bogota deficit mas 1'500000 arbol minimo deber arbol 3 habitan reserva der hammen poseer fuente agua subterrranea seguir sembrar_arbol reserva 2do necesario pulmon aire bogota despues cerro oriental
#
# brasil querer respiro naturaleza
#
# gustavo_petro urrego presidente colombia ultraderecha donald_trump humanida salida unidos cambio climatico desastre climatico mundial favorecer interes grande compania_petrolero unidos interes poblacion mundial contrario gustavo_petro presidente defender interes poblacion colombiano cambio climatico
#
# uribestias procuragodo infartado 3 2 1 v medio lanzamiento cumbre_clima secretaria distrital ambiente susana_muhamad anuncio alcalde bogota gustavo_petro recibio invitacion vaticano tratar tema cambio climatico carta invitacion firmado marcelo sanchez sorondo indicar medio presenta invitar_participar coloquio titulado ' esclavitud moderno cambio climatico compromiso ciudad ' tendrar casina pio iv ciudad vaticano sede academia pontificia ciencia academia pontificia ciencia social coincidir presentacion enciclica_papa_francisco tratar tema reunion llevariar cabo proximo 21 22 julio objetivo encuentro segun invitacion generar_conciencia urgencia afectar mundo_entero forma moderno esclavitud cambio climatico coloquio servirir enriquecer debate acerca dimension moral proteccion medioambiente marco enciclica pronto publicar papa_francisco tematica anade comunicacion director relacion internacional distrito gustavo torres guerrero explicar mas ano invitacion asi invitar vaticano ban_kimoon habia barack_obama ano invitar cumbre_clima york manifesto adema revelo reunion vaticano hablar inclusion_social cambio climatico mas afectado mas vulnerable pobre
#
# nadama faltar culpir calentamiento_global inventar
#
# catarina inusual huracan_atlantico sur romper ley meteorologia catarin duda huracan mas raro jamas formado registro historico mundo extrano atlantico sur dinamica atmosferico temperatura oceanica favorable desarrollo ciclon forma permanente patron mantener vigente imposible desarrollo ciclon forma tropical fuerte cilladura vertical area convergencia temperatura oceanica fria factor principal mantener ausencia formacion 24_marzo 2004 ocurrio cientifico esperar oceano vaguada extratropical salio brasil moviendose oeste comenzo transicion ciclon subtropical condicion_atmosferica inusualmente favorable temperatura oceanica promedio perturbacion comenzo ciclogenesis tipico ciclon_tropical 25_marzo viento aumentar forma sorprendente 95kkmhconvirtiendolo unico tormenta_tropical atlantico sur adquirir nombre persistir condicion inusualmente favorable sistema alcanzo pico intensidad categoria categoria presion barometrico 972 mb viento maximo sostenido 155 kmh racha mas fuerte grande agencia meteorologica paralizado huracan escala oceano ostir ojo impacto santa_catarina provocar fuerte_lluvia viento_huracanado manejada ciclonica insidir zona aurora caribe imposible ocurrir causo 350 millon dano 1500 casa destruir dano severo producir mas agricultura 3 persona perder vida dia seguir huracan tema discusion extraordinario formacion asegurar calentamiento_global sistema podian mas frecuente

# %%
# %%time
# this is a bit time consuming - make the if statement True
# if you want to execute data prep yourself.

trigram_reviews_filepath = r'..\..\..\data\ngrams\full-data\trigram_transformed_reviews_all.txt'
trigram_reviews_filepath = trigram_sentences_filepath
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
print('Original:' + u'\n')
for review in it.islice(line_review(file_lemmatized_text), 11, 12):
    print(review)
print('----' + u'\n')
print('Transformed:' + u'\n')

with codecs.open(trigram_reviews_filepath, encoding='utf_8') as f:
    for review in it.islice(f, 11, 12):
        print(review)
# Out:
# Original:
#
# cambio climatico francisco febres cordero domingo 29 noviembre 2015 chuta interesante manana comenzar francia cumbre cambio climatico participar excelentisimo senor presidente republica buenazo discurso tambien economista experto cambio ay clima quise dominar tema ojala mundo seguir pie letra recomendacion claro preguntar president asistir cumbre despues parrafo refregar estudiante ano cosmetologia sera cosmografia ay dificil terminologia cientifico seguro revelacion basado experiencia climologo mas clima cambiar tomar medida urgente achicharrar habitante planeta explicar sentir carne calentar pais calle tambien calentar calle excelentisimo senor presidente republica cien mil persona salir gritar calientisimas alarmar mundo calentamiento mil noma reconocer calentamiento tornar global jubilado afiliado desempleado trabajador indigena profesor perseguido peor sumar gas ordenar tirar serrano atentar capa ozono pobre calentado producir efecto invernadero pulmon horrible dano atmosferico despues explicar calentamiento clase calle pais ecuatorial producir sabado acumulacion azufre calentamiento mas modificar clima clima justicia asamblea empresario funcionario punto excelentisimo senor presidente republica descalentamiento global ahi aplaudir durisimo asistente cumbre capaz doctorado honoris causa climaterio alusion fenomeno generar oxigeno hablar yasuni ahi meter camisa once vara hablar mas reciclamiento evitar efecto invernadero ministro embajador embajador ministro ministro embajador ministro asi mas eclipse sol preparar querer seguir brillar unico estrella firmamento oxigeno necesario vida lindo conferencia ojala patino excelentisimo senor presidente republica corbata romper protocolo kioto estricto transmitir discurso cadena nacional asesor aconsejar hablar frances espanol entender
#
# ----
#
# Transformed:
#
# cambio climatico francisco febres cordero domingo 29_noviembre 2015 chuta interesante manana comenzar francia cumbre cambio climatico participar excelentisimo senor presidente_republica buenazo discurso tambien economista experto cambio ay clima quise dominar tema ojala mundo seguir pie letra recomendacion claro preguntar president asistir cumbre despues parrafo refregar estudiante ano cosmetologia sera cosmografia ay dificil terminologia cientifico seguro revelacion basado experiencia climologo mas clima cambiar tomar_medida_urgente achicharrar habitante planeta explicar sentir carne calentar pais calle tambien calentar calle excelentisimo senor presidente_republica cien mil persona salir gritar calientisimas alarmar mundo calentamiento mil noma reconocer calentamiento tornar global jubilado afiliado desempleado trabajador indigena profesor perseguido peor sumar gas ordenar tirar serrano atentar capa_ozono pobre calentado producir efecto_invernadero pulmon horrible dano atmosferico despues explicar calentamiento clase calle pais ecuatorial producir sabado acumulacion azufre calentamiento mas modificar clima clima justicia asamblea empresario funcionario punto excelentisimo senor presidente_republica descalentamiento global ahi aplaudir durisimo asistente cumbre capaz doctorado honoris causa climaterio alusion fenomeno generar oxigeno hablar yasuni ahi meter camisa once vara hablar mas reciclamiento evitar efecto_invernadero ministro embajador embajador ministro ministro embajador ministro asi mas eclipse sol preparar querer seguir brillar unico estrella firmamento oxigeno necesario vida lindo conferencia ojala patino excelentisimo senor presidente_republica corbata romper protocolo_kioto estricto transmitir discurso cadena nacional asesor aconsejar hablar frances espanol entender

# %% [markdown]
# # LDA

# %%
import warnings
import multiprocessing
from gensim.corpora import Dictionary, MmCorpus
from gensim.models.ldamulticore import LdaMulticore

# %%
trigram_dictionary_filepath = r'..\..\models\ngrams\full-data\trigram_dict_all.dict'

# %%
# %%time

# this is a bit time consuming - make the if statement True
# if you want to learn the dictionary yourself.
if 1 == 1:

    trigram_reviews = LineSentence(trigram_reviews_filepath)

    # learn the dictionary by iterating over all of the reviews
    trigram_dictionary = Dictionary(trigram_reviews)
    
    # filter tokens that are very rare or too common from
    # the dictionary (filter_extremes) and reassign integer ids (compactify)
    trigram_dictionary.filter_extremes(no_below=300, no_above=0.4)
    trigram_dictionary.compactify()

    trigram_dictionary.save(trigram_dictionary_filepath)
    
# load the finished dictionary from disk
trigram_dictionary = Dictionary.load(trigram_dictionary_filepath)
# Out:
# CPU times: total: 46.4 s
# Wall time: 46.5 s

# %%
trigram_bow_filepath = r'..\..\models\ngrams\full-data\trigram_bow_corpus_all.mm'

# %%
def trigram_bow_generator(filepath):
    """
    generator function to read reviews from a file
    and yield a bag-of-words representation
    """
    
    for review in LineSentence(filepath):
        yield trigram_dictionary.doc2bow(review)

# %%
# %%time

# this is a bit time consuming - make the if statement True
# if you want to build the bag-of-words corpus yourself.
if 1 == 1:
    # generate bag-of-words representations for
    # all reviews and save them as a matrix
    MmCorpus.serialize(trigram_bow_filepath,
                       trigram_bow_generator(trigram_reviews_filepath))
# load the finished bag-of-words corpus from disk
trigram_bow_corpus = MmCorpus(trigram_bow_filepath)
# Out:
# CPU times: total: 52.8 s
# Wall time: 53.1 s

# %%
lda_model_filepath = r'..\..\models\ngrams\full-data\lda_model_all'

# %%
pool = multiprocessing.Pool()
num_workers = pool._processes
print(f"Number of workers in the Pool: {num_workers}")
# Out:
# Number of workers in the Pool: 16

# %%
num_topics = 50

# %%
# %%time

# this is a bit time consuming - make the if statement True
# if you want to train the LDA model yourself.
if 1 == 1:

    with warnings.catch_warnings():
        warnings.simplefilter('ignore')
        
        # workers => sets the parallelism, and should be
        # set to your number of physical cores minus one
        lda = LdaMulticore(trigram_bow_corpus,
                           num_topics=num_topics,
                           id2word=trigram_dictionary,
                           workers=num_workers,
                           )
    
    lda.save(lda_model_filepath)
    
# load the finished LDA model from disk
lda = LdaMulticore.load(lda_model_filepath)

# %% [markdown]
# ## Keywords

# %%
from matplotlib import pyplot as plt
from wordcloud import WordCloud
import matplotlib.colors as mcolors

# %%
#cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'
cols = [color for name, color in mcolors.XKCD_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'
cols = cols[num_topics:num_topics*2]

cloud = WordCloud(background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(5, 2, figsize=(20,15), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
def explore_topic(topic_number, topn=25):
    """
    accept a user-supplied topic number and
    print out a formatted list of the top terms
    """
        
    print('{:20} {}'.format(u'term', u'frequency') + u'\n')

    for term, frequency in lda.show_topic(topic_number, topn=topn):
        print('{:20} {:.3f}'.format(term, round(frequency, 3)))

# %%
for topic in range(20):
    print(f"--- Topic: {topic}")
    explore_topic(topic_number=topic, topn=10)
    print("")
# Out:
# --- Topic: 0
# term                 frequency
#
# mas                  0.023
# energia              0.008
# cientifico           0.008
# ano                  0.007
# tierra               0.005
# clima                0.004
# planeta              0.004
# ciencia              0.004
# politico             0.004
# calentamiento_global 0.003
#
# --- Topic: 1
# term                 frequency
#
# cambioclimatico      0.013
# lucha                0.010
# mujer                0.010
# calentamiento_global 0.009
# mas                  0.008
# mundo                0.007
# hablar               0.007
# tema                 0.006
# internacional        0.005
# dia                  0.004
#
# --- Topic: 2
# term                 frequency
#
# mas                  0.009
# dia                  0.007
# noticia              0.007
# compartir            0.006
# agua                 0.006
# pierdar              0.005
# clima                0.004
# ano                  0.004
# hora                 0.003
# calentamiento_global 0.003
#
# --- Topic: 3
# term                 frequency
#
# ambiental            0.010
# proyecto             0.009
# mas                  0.007
# programa             0.006
# actividad            0.006
# asi                  0.004
# municipio            0.004
# medio_ambiente       0.004
# area                 0.004
# traves               0.004
#
# --- Topic: 4
# term                 frequency
#
# oceano               0.017
# agua                 0.013
# mas                  0.012
# mar                  0.010
# ecosistema           0.008
# especie              0.007
# impacto              0.007
# mundo                0.007
# afectar              0.006
# efecto               0.006
#
# --- Topic: 5
# term                 frequency
#
# mas                  0.010
# mundo                0.008
# calentamiento_global 0.007
# ano                  0.006
# ciudad               0.006
# agua                 0.006
# planeta              0.006
# tambien              0.005
# cambio               0.004
# tierra               0.003
#
# --- Topic: 6
# term                 frequency
#
# mas                  0.019
# humano               0.018
# naturaleza           0.013
# animal               0.011
# especie              0.011
# planeta              0.010
# vida                 0.010
# mundo                0.009
# tierra               0.009
# tambien              0.009
#
# --- Topic: 7
# term                 frequency
#
# mas                  0.015
# hora_planeta         0.011
# ano                  0.008
# mundo                0.007
# ciudad               0.006
# tambien              0.004
# mundial              0.003
# pais                 0.003
# jujuy                0.003
# ambiental            0.003
#
# --- Topic: 8
# term                 frequency
#
# mas                  0.008
# desarrollo           0.008
# proyecto             0.007
# nacional             0.006
# ambiental            0.005
# objetivo             0.005
# acción               0.005
# internacional        0.005
# iniciativa           0.005
# sostenible           0.005
#
# --- Topic: 9
# term                 frequency
#
# mas                  0.027
# ano                  0.010
# agua                 0.009
# calentamiento_global 0.008
# podriar              0.005
# planeta              0.005
# mundo                0.005
# zona                 0.005
# tambien              0.004
# temperatura          0.004
#
# --- Topic: 10
# term                 frequency
#
# arbol                0.021
# mas                  0.016
# dia                  0.012
# bosque               0.009
# medio_ambiente       0.008
# ciudad               0.008
# tierra               0.007
# planeta              0.007
# acción               0.007
# proteger             0.006
#
# --- Topic: 11
# term                 frequency
#
# mas                  0.019
# tierra               0.009
# ano                  0.008
# mundo                0.007
# planeta              0.006
# cientifico           0.006
# vida                 0.006
# podriar              0.005
# deber                0.005
# humano               0.005
#
# --- Topic: 12
# term                 frequency
#
# mas                  0.024
# ano                  0.018
# mundo                0.006
# país                 0.005
# tambien              0.005
# persona              0.005
# empresa              0.004
# energia              0.004
# dia                  0.003
# semana               0.003
#
# --- Topic: 13
# term                 frequency
#
# mas                  0.025
# dia                  0.014
# planeta              0.013
# mundo                0.011
# vida                 0.009
# calentamiento_global 0.008
# ano                  0.008
# tierra               0.007
# vivir                0.006
# persona              0.006
#
# --- Topic: 14
# term                 frequency
#
# '                    0.084
# mas                  0.016
# mundo                0.007
# ano                  0.006
# mujer                0.005
# agua                 0.004
# vida                 0.004
# tambien              0.004
# suelo                0.003
# tierra               0.003
#
# --- Topic: 15
# term                 frequency
#
# mas                  0.010
# and                  0.006
# the                  0.006
# mundo                0.005
# 1                    0.005
# seguir               0.004
# 3                    0.004
# 2                    0.003
# of                   0.003
# in                   0.003
#
# --- Topic: 16
# term                 frequency
#
# mas                  0.015
# mundo                0.014
# ano                  0.008
# salud                0.006
# planeta              0.006
# global               0.006
# tierra               0.006
# mundial              0.005
# vida                 0.005
# humano               0.004
#
# --- Topic: 17
# term                 frequency
#
# agua                 0.014
# mas                  0.010
# obra                 0.005
# ano                  0.005
# proyecto             0.005
# dia                  0.005
# municipio            0.004
# tambien              0.004
# gobierno             0.004
# ciudad               0.004
#
# --- Topic: 18
# term                 frequency
#
# gobierno             0.012
# mas                  0.011
# pais                 0.008
# tambien              0.006
# presidente           0.006
# deber                0.005
# mexico               0.005
# ley                  0.004
# politica             0.004
# unidos               0.004
#
# --- Topic: 19
# term                 frequency
#
# mas                  0.015
# tambien              0.007
# ano                  0.007
# planeta              0.006
# dia                  0.004
# proyecto             0.004
# utilizar             0.003
# persona              0.003
# forma                0.003
# energia              0.003
