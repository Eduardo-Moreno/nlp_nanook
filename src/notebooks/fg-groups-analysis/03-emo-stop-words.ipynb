# %%
import pandas as pd
import sys
import pickle
#sys.path.insert(0, '/Users/eduardomorenoortiz/Desktop/ITAM/nanook/nlp_nanook/src/') # LOCAL
sys.path.insert(0, r'C:\Users\eduardo.moreno\OneDrive - NEORIS\Desktop\courses\nlp\nlp_nanook\src') # Windows
from utils.utils import remove_stop_words_from_dataframe

# %% [markdown]
# # Read and preprocess data

# %%
df_stemm_lemm = pd.read_pickle(r'..\..\..\data\preprocessed\stemm_lemm_text_fb_groups_nanook.pkl')

# %%
df_select = df_stemm_lemm[
    [
        'Facebook Id', 'Post Created', 
        'Total Interactions', 'Likes', 'Comments', 'Shares', 'Love', 'Wow', 'Haha', 'Sad', 'Angry', 'Care', 
        'Message', 'Message_clean', 'Message_clean_stemm', 'Message_clean_lemm',
        ]
    ]
df_select.head(1)
# Out:
#        Facebook Id             Post Created Total Interactions  Likes  \
# 0  153630631414604  2016-01-05 20:55:17 CST              7,836   7266
#
#    Comments  Shares  Love  Wow  Haha  Sad  Angry  Care  \
# 0       442      63    51    1     9    2      0     2
#
#                                              Message  \
# 0  A LOS NACIDOS ENTRE 1970 Y 1987 Somos una gene...
#
#                                        Message_clean  \
# 0  a los nacidos entre 1970 y 1987 somos una gene...
#
#                                  Message_clean_stemm  \
# 0  a los nac entre 1970 y 1987 som una gener espe...
#
#                                   Message_clean_lemm
# 0  a el nacido entre 1970 y 1987 ser uno generaci...

# %% [markdown]
# Remove stop words from messages

# %%
df_clean = remove_stop_words_from_dataframe(
    df=df_select, 
    columns=["Message", "Message_clean", "Message_clean_stemm", "Message_clean_lemm"], 
    stop_words_file=r"..\..\utils\spanish_stopwords.txt"
    )
# Out:
# C:\Users\eduardo.moreno\OneDrive - NEORIS\Desktop\courses\nlp\nlp_nanook\src\utils\utils.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column + '_stpWrd'] = aux
# C:\Users\eduardo.moreno\OneDrive - NEORIS\Desktop\courses\nlp\nlp_nanook\src\utils\utils.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column + '_stpWrd'] = aux
# C:\Users\eduardo.moreno\OneDrive - NEORIS\Desktop\courses\nlp\nlp_nanook\src\utils\utils.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column + '_stpWrd'] = aux
# C:\Users\eduardo.moreno\OneDrive - NEORIS\Desktop\courses\nlp\nlp_nanook\src\utils\utils.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column + '_stpWrd'] = aux

# %%
df_clean[
    [
        'Message_clean', 'Message_clean_stpWrd',
        'Message_clean_stemm', 'Message_clean_stemm_stpWrd',
        'Message_clean_lemm', 'Message_clean_lemm_stpWrd'
        ]].head(1)
# Out:
#                                        Message_clean  \
# 0  a los nacidos entre 1970 y 1987 somos una gene...
#
#                                 Message_clean_stpWrd  \
# 0  nacidos 1970 1987 generacion especial denomina...
#
#                                  Message_clean_stemm  \
# 0  a los nac entre 1970 y 1987 som una gener espe...
#
#                           Message_clean_stemm_stpWrd  \
# 0  nac 1970 1987 som gener especial denomin gener...
#
#                                   Message_clean_lemm  \
# 0  a el nacido entre 1970 y 1987 ser uno generaci...
#
#                            Message_clean_lemm_stpWrd
# 0  nacido 1970 1987 generacion especial denominar...

# %% [markdown]
# Save final dataframe

# %%
df_clean[['Facebook Id', 'Post Created', 'Total Interactions', 'Likes',
       'Comments', 'Shares', 'Love', 'Wow', 'Haha', 'Sad', 'Angry', 'Care',
       'Message', 'Message_stpWrd', 'Message_clean_stpWrd', 'Message_clean_stemm_stpWrd',
       'Message_clean_lemm_stpWrd']].to_pickle(r"..\..\..\data\preprocessed\stemm_lemm_stop_words_stop_fb_groups.pkl")
