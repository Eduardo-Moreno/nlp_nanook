# %%
import pandas as pd
import random
import sys
#sys.path.insert(0, '/Users/eduardomorenoortiz/Desktop/ITAM/nanook/nlp_nanook/src') # Local
sys.path.insert(0, r'C:\Users\eduardo.moreno\OneDrive - NEORIS\Desktop\courses\nlp\nlp_nanook\src') # Windows
from utils.utils import  clean_text, get_corpus_N_gram

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Read and preprocess data

# %%
data = pd.read_pickle(r'..\..\..\data\preprocessed\data_fb_groups.pkl')

# %%
data.columns
# Out:
# Index(['Entity Name', 'Facebook Id', 'Likes at Posting', 'Post Created',
#        'Type', 'Total Interactions', 'Likes', 'Comments', 'Shares', 'Love',
#        'Wow', 'Haha', 'Sad', 'Angry', 'Care', 'Message', 'Image Text',
#        'Link Text', 'Description', 'score', 'source'],
#       dtype='object')

# %%
df_selected = data[['Facebook Id', 'Likes at Posting', 'Post Created', 'Type', 
                    'Total Interactions', 'Likes', 'Comments', 'Shares', 'Love', 'Wow', 'Haha', 'Sad', 'Angry', 'Care', 'Message', 'Image Text', 'Link Text', 'Description', 
                    'score']]

# %%
df_selected.head()
# Out:
#        Facebook Id  Likes at Posting             Post Created   Type  \
# 0  153630631414604               NaN  2016-01-05 20:55:17 CST  Photo
# 1  344760762323803               NaN  2018-03-25 20:22:33 CST  Photo
# 2  663135523805166               NaN  2018-04-26 15:23:31 CDT  Photo
# 3  461295120574213               NaN  2016-05-02 17:59:04 CDT  Photo
# 4  663135523805166               NaN  2016-06-28 23:41:26 CDT  Photo
#
#   Total Interactions  Likes  Comments  Shares  Love  Wow  Haha  Sad  Angry  \
# 0              7,836   7266       442      63    51    1     9    2      0
# 1             12,530   2946        44    9025   357    4   112    7     17
# 2              3,727   2137        77     917   583   10     2    0      1
# 3              3,146   2548       249     188   123    7    28    2      1
# 4              2,804   2367        57     181    87    5     3    8     96
#
#    Care                                            Message Image Text  \
# 0     2  A LOS NACIDOS ENTRE 1970 Y 1987 Somos una gene...        NaN
# 1    18  PORQUE VOTARE POR GUSTAVO PETRO Hoy quiero com...        NaN
# 2     0  Ministra de medio ambiente, a trabajar por el ...        NaN
# 3     0  A LOS NACIDOS ENTRE 1970 Y 1987 Somos una gene...        NaN
# 4     0  AYÚDANOS A COMPARTIR LA IMAGEN.. Por tan magni...        NaN
#
#   Link Text Description   score
# 0       NaN         NaN   36.28
# 1       NaN         NaN  338.65
# 2       NaN         NaN   29.12
# 3       NaN         NaN   22.31
# 4       NaN         NaN   21.91

# %%
df_selected.shape
# Out:
# (287180, 19)

# %% [markdown]
# Drop *nan* inside `Message` column

# %%
print(f"Cantidad de NAN: {sum([1 if pd.isna(x) else 0 for x in df_selected['Message']])}")
print(f"Cantidad de NAN (%): {round(sum([1 if pd.isna(x) else 0 for x in df_selected['Message']])/df_selected.shape[0]*100, 5)}%")
df_clean = df_selected.dropna(subset=['Message'])
# Out:
# Cantidad de NAN: 158
# Cantidad de NAN (%): 0.05502%

# %%
df_clean = df_clean.reset_index()

# %% [markdown]
# Show some messages

# %%
random.seed(14112023)
for i in random.sample(range(0, df_clean.shape[0]), 10):
    print(df_clean['Message'][i])
    print('\n')
# Out:
# 🔴[EN VIVO: 12 Y 14 DE MAYO] ►CURSO GRATUITO EN: CAMBIO CLIMÁTICO ------------------------------------- 📝Registro para la certificación del curso aquí: https://www.inagep.com/cambioclimatico.html -------------------------------------- 🦾 Recibe un recordatorio del día del evento aquí: https://bit.ly/3xkaOxM ------------------------------------- 🔸Para recibir cursos, material, noticias y normativa sobre temas relacionados a Ingeniería y medio ambiente suscríbete aquí: https://www.facebook.com/groups/3604704412954311/ ------------------------------------- 🔸Puedes verlo en: 💻 link YouTube: https://youtube.com/c/inagep 💻 Link Twitter:https://twitter.com/inagepoficial ------------------------------------ 🔥Se escogerá a un ganador (1) de entre todos los que comparten el banner y la transmisión el mismo día del en vivo, y respondan la pregunta al final de la clase.
#
#
# ALERTA: ¡FACEBOOK ESTÁ INTENTANDO BLOQUEAR ESTE POST PARA EVITAR QUE LUCHES CONTRA JOE BIDFEN Y LOS SQUADS INTENTAN DESTRUIR LA ECONOMÍA DE EE. UU. Y CONDUCIR TRABAJOS A CHINA Y OTROS PAÍSES DE TRABAJADORES ESCLAVOS! ¡LUCHA DETRÁS DIFUSIENDO ESTE POST A TODO LADO! NOTICIAS DE ÚLTIMA HORA: Texas contraataca a los bancos de Wall Street contra los combustibles fósiles y prácticamente a todos los principales administradores de activos que declaran su cambio y / o están boicoteando las inversiones en combustibles fósiles. TEXANOS Y TODOS LOS DEMÁS, CONTACTE A SUS LEGISLADORES ESTATALES Y EXIJA QUE LA LEGISLACIÓN APROBADA BOICOTEAR A TODOS LOS Bancos de Wall Street contra los combustibles fósiles y prácticamente a todos los principales administradores de activos que declaran su cambio y / o están boicoteando las inversiones en combustibles fósiles. ESTA ES SU OPORTUNIDAD DE LUCHAR Y DERROTAR LAS ÓRDENES EJECUTIVAS ILEGALES DEL CORRUPTO JOE BIDEN Y EL NUEVO ACUERDO VERDE DEL SQUAD QUE DEJARÁ A MILLONES DE ESTADOS UNIDOS SIN TRABAJO AL CAMBIAR TRABAJOS A CHINA Y OTROS PAÍSES DE TRABAJO ESCLAVO Y AUMENTAR LOS COSTOS DE ENERGÍA DE EE. UU. Por Irina Slav - 12 de marzo de 2021, 11:30 a. M. CST A medida que un número creciente de bancos de Wall Street y prácticamente todos los principales administradores de activos declaran su alejamiento de las inversiones en combustibles fósiles, el Senado de Texas contraataca con un proyecto de ley que propone que los fondos de inversión del estado salgan de todas las empresas que "boicotean" el petróleo y el gas. El Texas Tribune informa que el proyecto de ley, propuesto por cinco senadores republicanos, cubre entidades estatales como el Fondo Escolar Permanente de Texas de $ 46 mil millones, el Sistema de Jubilación de Maestros de Texas y el Sistema de Jubilación Municipal de Texas de Texas. Ambos tienen alrededor de $ 31 mil millones bajo administración. Si se aprueba, todas estas entidades y más estarán obligadas a salir de las empresas que "se nieguen a negociar, poner fin a las actividades comerciales o tomar cualquier medida que tenga la intención de penalizar, infligir daño económico o limitar las relaciones comerciales con una empresa". porque esta empresa se dedica a la exploración y producción de petróleo. El proyecto de ley también estipula que ninguna empresa o individuo puede demandar a las entidades estatales por desinvertir en empresas que se niegan a invertir en la industria de los combustibles fósiles. Ya seis de los prestamistas más grandes de EE. UU. Se han comprometido oficialmente a trabajar para lograr los objetivos establecidos en el Acuerdo de París sobre el Cambio Climático. Básicamente, estos compromisos se reducen a que los bancos dicen que su objetivo es llegar a cero en términos de los proyectos que financian durante un cierto período de tiempo. Esto significa que pueden estar en camino enormes desinversiones de petróleo y gas, lo que naturalmente ha provocado problemas de petróleo y gas. Los bancos están confusos en los detalles en general. Se habla de reducir la exposición al petróleo y el gas y aumentar la exposición a los proyectos de energía limpia, pero algunos creen que esto no es suficiente y Wall Street debería prometer una salida total del petróleo y el gas. Según el vicegobernador Dan Patrick, el proyecto de ley, que también incluye una estipulación para la desinversión forzosa, debería aprobarse fácilmente. Por Irina Slav para Oilprice.com
#
#
# Donald Trump: "El concepto de calentamiento global fue creado por y para los chinos para hacer no competitiva a la manufactura de EE UU”... Los glaciares de Tierra del Fuego nos dicen algo distinto...
#
#
# Planta un árbol al año, será de gran beneficio para todos🌳🌏 #EcoRetoBolivia #BloqueMeyerDelSur #DíaInternacionalDelÁrbol
#
#
# Friday For The Future ha promovido la marcha internacional Acción Global por el Clima que ha movilizado a jóvenes andaluces, españoles y de todas partes del mundo para exigir medidas urgentes contra la crisis climática. "... la solución pasa por “abandonar los combustibles fósiles, preservar los parques naturales y cambiar las formas de consumo y el estilo de vida de la población actual”. Unas reivindicaciones que ya se mencionan en el Acuerdo de París y que la juventud actual reclama “de manera inmediata”..."
#
#
# Mientras el café se enfría, hablemos de cambio climático. En nuestro primer conversatorio hablaremos sobre los retrocesos de glaciares en el contexto de cambio climático y sus implicaciones. Bienvenidos.
#
#
# Te invitamos a que te suscribes para ver nuestros temas de las Naciones Unidas en Español u otros idiomas
#
#
# Ojo con esto
#
#
# DIP. PERPULI PROPONE NUEVA LEY DE EQUILIBRIO ECOLOGICO Y PROTECCION AL AMBIENTE Contempla mecanismos, programas e instrumentos de política ambiental para el desarrollo sustentable. Incorpora y deja intocadas, las reformas llevadas a cabo en la prohibición de bolsas de plástico y los popotes. Así mismo, propone avanzar hacia una cultura en materia de reciclaje entre la sociedad sudcaliforniana. “Los recursos naturales del estado cuyo goce y disfrute corresponde a todos los sudcalifornianos, se encuentran bajo constante amenaza de deterioro, por eso es tiempo de que se analice una ley de protección al ambiente de vanguardia cuyo propósito fundamental sea garantizar en todas las vertientes, el derecho humano a un medio ambiente sano, que propicie y fortalezca la posibilidad de bienestar y desarrollo colectivo para los próximos años” afirmo el Diputado José Luis Perpuli Drew al presentar este martes 23 de junio ante el Congreso del Estado, la iniciativa que crea una nueva Ley de Equilibrio Ecológico y Protección del Ambiente para el Estado de Baja California Sur que propone abrogar la existente QUE DATA El cuerpo de la iniciativa, consta de 194 artículos distribuida en nueve títulos, el primero de ellos, destinado a establecer las Disposiciones Generales, el segundo de la Política Ambiental para el Desarrollo Sustentable en el Estado y sus Instrumentos, el tercero referente a las Áreas Naturales Protegidas de Competencia Estatal, el cuarto refiere a la Protección y Cuidado de la Vida Silvestre Terrestre y Acuática, el quinto es sobre El Aprovechamiento Sustentable de los Recursos Naturales y la Protección al Ambiente, el sexto es en referencia a la Regulación de Actividades que puedan Generar Efectos Nocivos, el séptimo refiere a los Prestadores de Servicios Ambientales, el octavo a la Regulación de Acciones ante el Cambio Climático, y finalmente, el noveno es respecto al Procedimiento Administrativo, Medidas de Control, Infracciones y Sanciones. En general, la propuesta legislativa otorga certeza en los procesos administrativos de la autoridad ambiental, en cuanto a requisitos, tiempos de respuesta, procedimiento, recursos de inconformidad para recurrir las resoluciones que dicte la autoridad estatal y municipal con arreglo en la presente ley. Incluye la flexibilización para autorización en materia de impacto ambiental de obras y actividades que se encuentren dentro de un Centro de Población con Programa de Desarrollo Urbano, o sujetas a Ordenamientos Ecológicos, simplificando el trámite. En el caso del impacto ambiental de competencia municipal, permite que se realice la evaluación de manera unificada en el trámite de uso de suelo municipal. Se establecen claramente excepciones a obras y actividades en materia de impacto ambiental, en casos específicos debidamente descritos en la iniciativa de Ley, evitando la sobrerregulación. Se incluyen procedimientos claros para los procesos de decreto de áreas naturales protegidas estatales o municipales; así como para programas de ordenamiento ecológico estatal y municipal hoy no descritos en la Ley vigente. No crea obligaciones nuevas para los particulares, al contrario brinda transparencia y certeza, respecto de la Ley vigente. Incorpora y deja intocadas, las reformas llevadas a cabo en la prohibición de bolsas de plástico y los popotes. Así mismo, propone avanzar hacia una cultura en materia de reciclaje entre la sociedad sudcaliforniana. Al término de la exposición de motivos, el legislador loretano expuso que “la iniciativa que hoy se presenta es una propuesta inacabada, que necesariamente deberá ser fortalecida con las aportaciones de la comunidad científica, de los estudiosos de la materia tanto en su aspecto estrictamente ambiental y de los que estudian las normas jurídicas nacionales e internacionales que la soportan, de las organizaciones no gubernamentales, de las autoridades estatales y municipales, pero sobre todo, debe someterse al riguroso escrutinio de todos los sectores so ...
#
#
# 🙋🏻‍♀️¡¡Cuidar nuestros recursos naturales🌵🌎💧 debe ser un proposito para toda la humanidad este 2021!! 🌳🌳🌳EcoHouse te invita a su Diplomado Ambiental 📚📖 de hogares ecológicos 🏕️🏠🏡 **GRATIS desde el 5 al 9 de Abril/21* 🏡 *Módulos:* 🌱 Calentamiento global y gestión de residuos sólidos 🌱 Compostaje casero y manejo adecuado del aceite 🌱 Huertas caseras y biopreparados 🌱 Consumo responsable 🌱 Invitación especial *HORARIO:*⏰ CLASES EN VIVO y quedarán grabadas por si no puedes verlas en este horario o quieres repetirla. **De Lunes a Viernes: 8:00 pm hora Colombia.* *VIA YOUTUBE*📲💻 Queremos que seas parte del cambio.👏🌎🏘️🏡 *Únete y participa en el curso básico gratuito*.👇🏼👇🏼👇🏼👇🏼👇🏼 https://chat.whatsapp.com/G5sC1nYbphnFrwWIs7Pbea

# %% [markdown]
# ### Length of Messages

# %%
df_clean['messageChar_length'] = [x if pd.isna(x) else len(x) for x in df_clean['Message']]
df_clean['messageWords_length'] = [x if pd.isna(x) else len(x.split(' ')) for x in df_clean['Message']]

# %%
df_clean['messageChar_length'].plot(bins=150, kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# It is curious that there are "a lot" of messages with length aproximatly to $5,000$

# %%
df_clean['messageChar_length'].describe()
# Out:
# count    287022.000000
# mean        953.108936
# std        1381.139662
# min           1.000000
# 25%         110.000000
# 50%         321.000000
# 75%        1053.000000
# max        5000.000000
# Name: messageChar_length, dtype: float64

# %%
df_clean[df_clean['messageChar_length'] == 5000]['Message'][166429]
# Out:
# 'El Covid-19 y el retorno de la barbarie Por Víctor M. Toledo La barbarie en la historia humana es sinónimo de intolerancia y, en consecuencia, caldo fértil para el clasismo y racismo y para el advenimiento de sociedades totalitarias, pero también de gritos de rabia, radicalismo y desespera-ción que alimentan la sinrazón y niegan los aportes de la ciencia. En plena era digital, con 4 mil 540 millones de internautas, 60 por ciento de la población humana conectada a Internet, la crisis del mundo moderno parece inducir un nuevo florecimiento de la barbarie, del fanatismo de diversos colores, olores y sabores, ahora inducido, expandido y multiplicado por la red global y los medios de comunicación. Quienes pensaban que se habían superado los viejos tiempos oscuros y que la ciencia daría lugar a sociedades y ciudadanos orientados por el conocimiento objetivo y la razón, o por la pasión y la razón en conjunción equilibrada, hoy deben aceptar que padecían de un excesivo optimismo. Con un panorama que parece repetirse justo un siglo después, aunque con sus especificidades, la barbarie retorna. Con las dos guerras mundiales, la humanidad alcanzó sus máximos niveles de locura. Ello costó la vida de unos 120 millones de personas y la destrucción de ciudades, industrias, obras, infraestructuras y el dolor de millones de familias. Ese vórtice de muerte estuvo alimentado por el liberalismo, el fascismo y el comunismo, tolerado e incluso apoyado por los tres grandes monoteísmos (cristianismo, judaísmo e islamismo). Ello tuvo como núcleo, como eje disparador, a Europa, que se suponía era la cúspide de la civilización y que hoy debe enfrentarse a su propio declive. Con el arribo del Covid-19, la barbarie se expande y reproduce a toda velocidad por los nuevos medios, y se oculta en discursos que parecen fundamentados en una suerte de analfabetismo digital, facilitado por la brevedad y la velocidad de los mensajes. Ya no es sólo la fe religiosa o el dogmatismo político de izquierda y derecha convertida en ceguera, sino un sinfín de creencias insostenibles a la luz de la razón y de la ciencia. Que dos sicópatas estén gobernando los dos países más grandes de América es la primera y mayor expresión del retorno de la barbarie. Ambos fueron elegidos democráticamente. El problema no son entonces Donald Trump o Jair Bolsonaro, lo realmente preocupante son las mentes de quienes votaron por ellos. ¿Qué valores reconocieron en la figura de Trump, el magnate que durante cuatro años se comportó como un individuo clasista, mentiroso, racista, misógino, acechador sexual, anticientífico, negador del cambio climático, acusado de violar leyes y de evadir el pago de impuestos, los 71 millones que votaron por él en los comicios pasados? ¿Coinciden con sus posturas o una extraña ceguera les impide verlas? ¿Dónde quedó la ética en esos votantes? El caso brasileño no se queda atrás. En el país del carnaval y el glamur tropical, 49 millones votaron por Bolsonaro en 2018, un ex militar y parlamentario racista, homofóbico, misógino y violento, con declaraciones como: “hay que dar seis horas para que los delincuentes se entreguen; si no, se ametralla el barrio pobre desde el aire…” “vamos a fusilar a los militantes de izquierda…” “las comunidades negras no hacen nada, no sirven ni para procrear…” el error de la dictadura fue torturar y no matar... La samba de la muerte en la figura de un presidente. En el contexto de la pandemia, estas dos figuras políticas encabezan las teorías de la conspiración que afirman que la llegada del virus fue inducida y provocada por fuerzas todopoderosas (como el gobierno chino), en plena complicidad con la Organización Mundial de la Salud y las corporaciones farmacéuticas. En consecuencia, las vacunas son un invento mercantil inservible. Esta misma posición ha sido adoptada por millones según se lee en las redes sociales, pero también por innumerables intelectuales (de izquierda y derecha) y por prelados como el cardenal Juan Sandoval en def ...

# %%
for x in df_clean[df_clean['messageChar_length'] == 4999]['Message']:
    print(x[-20:])
# Out:
#  pobreza (truncated)
#  ley del (truncated)
# ecesario (truncated)
# , y unos (truncated)
# e estima (truncated)
# llevaron (truncated)
# otoBlog, (truncated)
# ones del (truncated)
# peratura (truncated)
# ideraban (truncated)
# fundas y (truncated)
# Torrico. (truncated)
# onsables (truncated)
# a calle, (truncated)
# cimiento (truncated)
# bilidad. (truncated)
#  en 2017 (truncated)
# cimiento (truncated)
#  países? (truncated)
# océanos, (truncated)
# torio de (truncated)
# ntrol de (truncated)
# ero sólo (truncated)
# LA ÉPOCA (truncated)
#  vida en (truncated)
# urístico (truncated)
# ero sólo (truncated)
#  a la 5ª (truncated)
# ienen al (truncated)
# e, donde (truncated)
# brientos (truncated)
# stado de (truncated)
# os donde (truncated)
# ero sólo (truncated)
# hasta tu (truncated)
# opuestas (truncated)
# minacion (truncated)
# hat ¡POR (truncated)
#  espacio (truncated)
# zados el (truncated)
# existía, (truncated)
#  la isla (truncated)
# na marcó (truncated)
#  interés (truncated)
# cidad de (truncated)
#  NUESTRA (truncated)
# entes se (truncated)
# ectaría, (truncated)
# incluso, (truncated)
# antabria (truncated)
# aña sólo (truncated)
# e Estado (truncated)
# ER MEJOR (truncated)
# entrales (truncated)
# e Puerto (truncated)
# cional a (truncated)
# fricanas (truncated)
# atentado (truncated)
# se había (truncated)
# opuestas (truncated)
# blar con (truncated)
#  ley del (truncated)
# de poder (truncated)
# En torno (truncated)
# uros por (truncated)
# irritó a (truncated)
# e Estado (truncated)
# uramente (truncated)
# o. Trump (truncated)
# En torno (truncated)
# ricordia (truncated)
# s que el (truncated)
# a en los (truncated)
# or de un (truncated)
# te habló (truncated)
# de estos (truncated)
# r con el (truncated)
# e Estado (truncated)
# a, menos (truncated)
# n frágil (truncated)
# ción, si (truncated)
# sumiendo (truncated)
# ares que (truncated)
# ero sólo (truncated)
# ueblo no (truncated)
# bilidad. (truncated)
# ntificar (truncated)
#  el Amor (truncated)
# rados en (truncated)
# os meses (truncated)
# l famoso (truncated)
# iado por (truncated)
# ctivo ha (truncated)
# ción del (truncated)
# e España (truncated)
# l que no (truncated)
# riginal) (truncated)
# ro de la (truncated)
# uipo. Va (truncated)
# tificial (truncated)
#  la vida (truncated)
# fundas y (truncated)
# ricordia (truncated)
# minacion (truncated)
# l riesgo (truncated)
# no en el (truncated)
# IDEOS DE (truncated)
# arrasado (truncated)
# tículas, (truncated)
# yendo de (truncated)
# alvar tu (truncated)
# aldía de (truncated)
#  dará un (truncated)
# nejo del (truncated)
# idad. Es (truncated)
#  la vida (truncated)
# tículas, (truncated)
#  Twitter (truncated)
# e países (truncated)
# nanciera (truncated)
# s de los (truncated)
# taría la (truncated)
# ión' con (truncated)
# eñales y (truncated)
# radación (truncated)
# ero sólo (truncated)
# incluso, (truncated)
# ue en la (truncated)
# eguridad (truncated)
# culado a (truncated)
# istro de (truncated)
# entrales (truncated)
# demás va (truncated)
#  cima de (truncated)
# colgante (truncated)
# de estos (truncated)
# l TIPNIS (truncated)
# erecho a (truncated)
# pobrecer (truncated)
# ideraban (truncated)
# e Estado (truncated)
# e Estado (truncated)
# ndamente (truncated)
#  que ese (truncated)
# epunte”, (truncated)
# yoría de (truncated)
# elantada (truncated)
# e Estado (truncated)
# céntrico (truncated)
# staba en (truncated)
# dicación (truncated)
# ivirá en (truncated)
# a de los (truncated)
# de poder (truncated)
# es en el (truncated)
#  NUESTRA (truncated)
#  NUESTRA (truncated)
# la costa (truncated)
# ficativo (truncated)
# mbustión (truncated)
# lterreno (truncated)
# pción de (truncated)
# ersonas) (truncated)
# e ver al (truncated)
# r de los (truncated)
#  corazón (truncated)
#  100% de (truncated)
# peratura (truncated)
# e Estado (truncated)
# USO HACE (truncated)
# r ayudan (truncated)
# uar. Nos (truncated)
# rolongar (truncated)
# arada es (truncated)
# uros por (truncated)
# uros por (truncated)
#  Israel. (truncated)
# e Estado (truncated)
# avilloso (truncated)
# talismo, (truncated)
# uros por (truncated)
# bilidad. (truncated)
# ncianos, (truncated)
# arios de (truncated)
# icita al (truncated)
# ático se (truncated)
# elantada (truncated)
# minacion (truncated)
# nción de (truncated)
#  humanos (truncated)
# rino del (truncated)
#  Cabezas (truncated)
# arios de (truncated)
# ontes en (truncated)
# falta de (truncated)
# icanos”, (truncated)
#  el Amor (truncated)
# ón y por (truncated)
# l que no (truncated)
# ción por (truncated)
# yoría de (truncated)
# ersonas) (truncated)
#  LOS 650 (truncated)
# rcen sus (truncated)
# os en un (truncated)
# eras del (truncated)
# más de 3 (truncated)
# sús: Una (truncated)
# ólica de (truncated)
# uros por (truncated)
# de Avaaz (truncated)
# cimiento (truncated)
# lismos a (truncated)
# parencia (truncated)
# RACIONAL (truncated)
# radación (truncated)
# a más de (truncated)
# nem pasó (truncated)
# tros dos (truncated)
# aña sólo (truncated)
# es en la (truncated)
# egar. En (truncated)
#  Kennedy (truncated)
# unicipal (truncated)
# falta de (truncated)
# millones (truncated)
# tículas, (truncated)
# iciales, (truncated)
# dades de (truncated)
#  por eso (truncated)
# itorios. (truncated)
# itorios. (truncated)
# guye que (truncated)
# s fotos. (truncated)
# 8. 11:15 (truncated)
#  por eso (truncated)
# to de su (truncated)
# , Sassan (truncated)
# brevuelo (truncated)
#  que ese (truncated)
# A POR LA (truncated)
# ricordia (truncated)
# cia y la (truncated)
# o: 1.800 (truncated)
# el grupo (truncated)
# familias (truncated)
# egar. En (truncated)
# océanos, (truncated)
#  por eso (truncated)
# uipo. Va (truncated)
# a uno de (truncated)
# nuestros (truncated)
# so es lo (truncated)
# otencial (truncated)
# Beca HHH (truncated)
# ITUYENTE (truncated)
# ricordia (truncated)
#  por eso (truncated)
#  que ese (truncated)
# ersonas) (truncated)
#  445.568 (truncated)
# pción de (truncated)
# guir las (truncated)
#  Israel. (truncated)
# to de su (truncated)
# eso a la (truncated)
#  cambios (truncated)
# producen (truncated)
# producen (truncated)
#  G6 y la (truncated)
# e España (truncated)
#  Cabezas (truncated)
#  Cabezas (truncated)
# ON A LOS (truncated)
#  G6 y la (truncated)
# ca... si (truncated)
# ca... si (truncated)
# perficie (truncated)
# bilidad. (truncated)
# adas con (truncated)
# etros de (truncated)
#  que ese (truncated)
# el flujo (truncated)
# guye que (truncated)
# uros por (truncated)
# nes a su (truncated)
#  demanda (truncated)
#  el Amor (truncated)
# l Señor. (truncated)
# ideraban (truncated)
#  por los (truncated)
# o tomará (truncated)
# ticas se (truncated)
# za en su (truncated)
# Bruselas (truncated)
# frágil y (truncated)
# vigor el (truncated)
# r de los (truncated)
# estar de (truncated)
# vigor el (truncated)
# eso a la (truncated)
# ricordia (truncated)
# ricordia (truncated)
# uros por (truncated)
# rino del (truncated)
# (marinas (truncated)
#  (35.000 (truncated)
#  que ese (truncated)
#  humanos (truncated)
# ez Vara… (truncated)
# por cada (truncated)
# ros -que (truncated)
# l riesgo (truncated)
# ricordia (truncated)
# de estan (truncated)
#  Cabezas (truncated)
# eso a la (truncated)
# itorios. (truncated)
#  la ley, (truncated)
#  humanos (truncated)
#  atender (truncated)
#  humanos (truncated)
#  que ese (truncated)
#  o queso (truncated)
# respeten (truncated)
# as never (truncated)
# versidad (truncated)
# ersonas) (truncated)
# atacando (truncated)
# des bajo (truncated)
# comienzo (truncated)
# ricordia (truncated)
# egar. En (truncated)
# caigamos (truncated)
#  pérdida (truncated)
# ción del (truncated)
# aterales (truncated)
# tamiento (truncated)
# rancisco (truncated)
# l jueves (truncated)
#  • DOBLE (truncated)
#  debemos (truncated)
#  debemos (truncated)
# comodará (truncated)
# pitiendo (truncated)
# is en el (truncated)
# c. En el (truncated)
# avés del (truncated)
#  • DOBLE (truncated)
# ismos) y (truncated)
# o B, eso (truncated)
# ntifican (truncated)
# mino por (truncated)
# de Avaaz (truncated)
# l que no (truncated)
# aña sólo (truncated)
#  toda la (truncated)
#  Cabezas (truncated)
# a lámina (truncated)
# es – que (truncated)
# l que no (truncated)
# quisitos (truncated)
# e la EPA (truncated)
# elantada (truncated)
# egar. En (truncated)
# nes a su (truncated)
# ITUYENTE (truncated)
# nes a su (truncated)
#  humanos (truncated)
# ntencion (truncated)
# cia para (truncated)
# uros por (truncated)
#  sido la (truncated)
# nes a su (truncated)
# r de los (truncated)
# ón y por (truncated)
#  regards (truncated)
# a -- por (truncated)
#  humanos (truncated)
#  100% de (truncated)
#  NUESTRA (truncated)
# requiere (truncated)
# a CMNUCC (truncated)
# limentos (truncated)
# er todos (truncated)
# alvación (truncated)
# Entonces (truncated)
# AL EN EL (truncated)
# undación (truncated)
# e acceso (truncated)
# a lámina (truncated)
#  por eso (truncated)
# iene más (truncated)
#  todo el (truncated)
# tria que (truncated)
# egurarse (truncated)
# o mintió (truncated)
# o, llega (truncated)
# pensar a (truncated)
# iciales, (truncated)
# yoría de (truncated)
# os cinco (truncated)
# iciales, (truncated)
#  Granjas (truncated)
# de poder (truncated)
# yoría de (truncated)
#  (Manejo (truncated)
# quisitos (truncated)
# uditório (truncated)
# itorios. (truncated)
# lexible, (truncated)
# os el 70 (truncated)
# Empujada (truncated)
# radación (truncated)
# ático se (truncated)
# ricordia (truncated)
# eso a la (truncated)
# guir las (truncated)
# yoría de (truncated)
# quisitos (truncated)
# egar. En (truncated)
# oría del (truncated)
# r de los (truncated)
# a -- por (truncated)
#  humanos (truncated)
# sas bien (truncated)
# l riesgo (truncated)
# ez Vara… (truncated)
# irá a un (truncated)
# rticipar (truncated)
# ricordia (truncated)
# de estas (truncated)
# el de no (truncated)
# os el 70 (truncated)
# io, Juan (truncated)
#  UN ERE, (truncated)
# raciarse (truncated)
# limentos (truncated)
# de ambos (truncated)
# ón y por (truncated)
# rutzen‒, (truncated)
# ático se (truncated)
# zación y (truncated)
# emia del (truncated)
# a Comuna (truncated)
# a Comuna (truncated)
#  Sharia. (truncated)
# % de los (truncated)
# incluso, (truncated)
# a podría (truncated)
# egar. En (truncated)
# sumiendo (truncated)
#  humanos (truncated)
# r de los (truncated)
# a -- por (truncated)
# uros por (truncated)
# s, según (truncated)
#  atreves (truncated)
#  realizó (truncated)
# ible. El (truncated)
# pasearse (truncated)
# bsorción (truncated)
# ta y una (truncated)
# va. Si a (truncated)
#  vida de (truncated)
# itorios. (truncated)
# sesor en (truncated)
#  región. (truncated)
#  Granjas (truncated)
# e 25.000 (truncated)
# elerado. (truncated)
# pitiendo (truncated)
#  • DOBLE (truncated)
# de estos (truncated)
#  • DOBLE (truncated)
# AL EN EL (truncated)
# puede no (truncated)
# a lámina (truncated)
#  • DOBLE (truncated)
# AL EN EL (truncated)
# egrar el (truncated)
# aller se (truncated)
# nte $800 (truncated)
# mpañeros (truncated)
# idencia” (truncated)
# fomento, (truncated)
# e España (truncated)
# uros por (truncated)
# arrasado (truncated)
# ovocados (truncated)
# o así de (truncated)
# ntonces. (truncated)
#  Cabezas (truncated)
#  Cabezas (truncated)
# r eso es (truncated)
#  445.568 (truncated)
# n de una (truncated)
#  154.000 (truncated)
# Entonces (truncated)
# cios son (truncated)
# la aguja (truncated)
#  esposa, (truncated)
# r que el (truncated)
# guye que (truncated)
# ticas se (truncated)
# vida que (truncated)
# asillero (truncated)
#  de EEUU (truncated)
# adecuada (truncated)
# adecuada (truncated)
# guye que (truncated)
# cios son (truncated)
# ue todos (truncated)
# deración (truncated)
# y bajará (truncated)
#  de tres (truncated)
# n, “pero (truncated)
# ? Enviar (truncated)
# y siendo (truncated)
# RACIONAL (truncated)
# nes a su (truncated)
# e Estado (truncated)
# guye que (truncated)
# Entonces (truncated)
# de ambos (truncated)
# de ambos (truncated)
# ción con (truncated)
# no? Pues (truncated)
# BERNANTE (truncated)
#  Médico: (truncated)
# egar. En (truncated)
#  NUESTRA (truncated)
# r de los (truncated)
#  atender (truncated)
# as redes (truncated)
# , mañana (truncated)
# se sigan (truncated)
# a fecha, (truncated)
# públicas (truncated)
# públicas (truncated)
# AL EN EL (truncated)
#  • DOBLE (truncated)
# ienen al (truncated)
# zagados. (truncated)
# obiernos (truncated)
#  • DOBLE (truncated)
# sesor en (truncated)
# en 2016) (truncated)
# is en el (truncated)
# e 25.000 (truncated)
# no? Pues (truncated)
# sagiosos (truncated)
# RCO A TÍ (truncated)
# os el 70 (truncated)
# ático se (truncated)
# unicipal (truncated)
# sagiosos (truncated)
# cios son (truncated)
#  • DOBLE (truncated)
# yoría de (truncated)
# os el 70 (truncated)
# RCO A TÍ (truncated)
# ES Y LAS (truncated)
# e Estado (truncated)
# aximizar (truncated)
# scate de (truncated)
# incluso, (truncated)
# to de su (truncated)
# o que se (truncated)
#  humanos (truncated)
# pecie de (truncated)
# en 2016) (truncated)
# uesto de (truncated)
# egar. En (truncated)
#  • DOBLE (truncated)
# orgánica (truncated)
#  como él (truncated)
# ando que (truncated)
# ue es la (truncated)
# ático se (truncated)
# logramos (truncated)
# chas mas (truncated)
# guir las (truncated)
# AL EN EL (truncated)
# ces para (truncated)
#  como él (truncated)
# egar. En (truncated)
#  Cabezas (truncated)
# scate de (truncated)
# egar. En (truncated)
# to de su (truncated)
# stado de (truncated)
# ez Vara… (truncated)
# egar. En (truncated)
#  Cabezas (truncated)
# emia del (truncated)
# scate de (truncated)
#  Cabezas (truncated)
# ES Y LAS (truncated)
# a -- por (truncated)
# sumiendo (truncated)
#  humanos (truncated)
# rticipar (truncated)
#  Cabezas (truncated)
# se mismo (truncated)
# r de los (truncated)
# mente en (truncated)
# ITUYENTE (truncated)
# al hecho (truncated)
# ez Vara… (truncated)
# ontra el (truncated)
# en 2016) (truncated)
# ance que (truncated)
# l hielo, (truncated)
# en metas (truncated)
#  Cabezas (truncated)
# ES Y LAS (truncated)
# o, no se (truncated)
#  • DOBLE (truncated)
# a, según (truncated)
# peratura (truncated)
# raidores (truncated)
#  el Amor (truncated)
# omercial (truncated)
# icadores (truncated)
# se mismo (truncated)
# ... pero (truncated)
# e tienen (truncated)
# la gente (truncated)
# guye que (truncated)
# a Comuna (truncated)
# a Comuna (truncated)
# a Comuna (truncated)
# a Comuna (truncated)
# a Comuna (truncated)
# a Comuna (truncated)
# a Comuna (truncated)
# a Comuna (truncated)
# a Comuna (truncated)
# a Comuna (truncated)
#  Granjas (truncated)
# en 2016) (truncated)
# RCO A TÍ (truncated)
# en 2016) (truncated)
# Entonces (truncated)
# no? Pues (truncated)
# cios son (truncated)
# Entonces (truncated)
# ares del (truncated)
#  palabra (truncated)
# تكون حرة (truncated)
# narán en (truncated)
# egar. En (truncated)
# er todos (truncated)
# ones que (truncated)
#  por eso (truncated)
# ria vida (truncated)
# r que el (truncated)
# lado que (truncated)
# a es uno (truncated)
#  influye (truncated)
# yoría de (truncated)
# uros por (truncated)
#  por eso (truncated)
#  Cabezas (truncated)
# pedia me (truncated)
# s dueños (truncated)
#  atreves (truncated)
# idos por (truncated)
# atada en (truncated)
# mica. En (truncated)
# sesor en (truncated)
# Lago del (truncated)
# entación (truncated)
# rtes del (truncated)
# préstamo (truncated)
# r eso es (truncated)
# ez Vara… (truncated)
# dades de (truncated)
# producen (truncated)
# de ambos (truncated)
# ntencion (truncated)
#  de esta (truncated)
# c. En el (truncated)
# c. En el (truncated)
# AL EN EL (truncated)
#  • DOBLE (truncated)
# AL EN EL (truncated)
#  menores (truncated)
#  • DOBLE (truncated)
# a uno de (truncated)
#  • DOBLE (truncated)
# cedentes (truncated)
# oderosos (truncated)
# c. En el (truncated)
#  • DOBLE (truncated)
#  grupos, (truncated)
# ctos que (truncated)
# nlaces a (truncated)
# is en el (truncated)
# ombres y (truncated)
# xtincion (truncated)
#  • DOBLE (truncated)
# AL EN EL (truncated)
#  • DOBLE (truncated)
# AL EN EL (truncated)
#  • DOBLE (truncated)
#  menores (truncated)
#  menores (truncated)
# AL EN EL (truncated)
#  • DOBLE (truncated)
#  humanos (truncated)
# AL EN EL (truncated)
#  • DOBLE (truncated)
#  • DOBLE (truncated)
# AL EN EL (truncated)
#  realizó (truncated)
# e 25.000 (truncated)
# AL EN EL (truncated)
# 7% de la (truncated)
# serie de (truncated)
# as, pero (truncated)
# lecer el (truncated)
#  • DOBLE (truncated)
#  • DOBLE (truncated)
# guir las (truncated)
# paración (truncated)
#  que les (truncated)
# ación de (truncated)
# ientras, (truncated)
# aller se (truncated)
# producen (truncated)
#  Estados (truncated)
# producen (truncated)
# l cambio (truncated)
# aller se (truncated)
# naron en (truncated)
# pedia me (truncated)
# s dueños (truncated)
# aller se (truncated)
# como las (truncated)
# irectiva (truncated)
# ... pero (truncated)
# fomento, (truncated)
# uros por (truncated)
# llevando (truncated)
# ue en su (truncated)
# uros por (truncated)
# 0, EN EL (truncated)
#  Cabezas (truncated)
# iños sin (truncated)
# تكون حرة (truncated)
# vigor el (truncated)
# BERNANTE (truncated)
# guye que (truncated)
# Entonces (truncated)
# cios son (truncated)
# Ambiente (truncated)
# a uno de (truncated)
# lado que (truncated)
# guye que (truncated)
#  humanos (truncated)
# guye que (truncated)
# cios son (truncated)
#  NUESTRA (truncated)
# egar. En (truncated)
# pregnado (truncated)
# haya más (truncated)
# vir cómo (truncated)
# egar. En (truncated)
#  • DOBLE (truncated)
#  • DOBLE (truncated)
# el de no (truncated)
# xtincion (truncated)
#  • DOBLE (truncated)
# ue todos (truncated)
# ón y por (truncated)
#  energía (truncated)
# egar. En (truncated)
# RACIONAL (truncated)
# ntro del (truncated)
# a el día (truncated)
#  son una (truncated)
# versidad (truncated)
# cios son (truncated)
# cios son (truncated)
# de ambos (truncated)
# Entonces (truncated)
# cios son (truncated)
# de ambos (truncated)
# Entonces (truncated)
# cios son (truncated)
# sagiosos (truncated)
# yoría de (truncated)
# Entonces (truncated)
# cios son (truncated)
# to de su (truncated)
#  NUESTRA (truncated)
# scate de (truncated)
# eso a la (truncated)
# ntencion (truncated)
# en estos (truncated)
#  humanos (truncated)
#  que ese (truncated)
# egar. En (truncated)
# stado de (truncated)
# st Mater (truncated)
# tra todo (truncated)
# raciarse (truncated)
# as redes (truncated)
# l hielo, (truncated)
#  segunda (truncated)
# go, Tutu (truncated)
# política (truncated)
#  todavía (truncated)
#  todavía (truncated)
#  todavía (truncated)
#  lógica, (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# causa de (truncated)
# positaba (truncated)
# positaba (truncated)
# del agua (truncated)
# tu casa, (truncated)
# hablando (truncated)
# rmas las (truncated)
# rmas las (truncated)
# rmas las (truncated)
# rmas las (truncated)
# rmas las (truncated)
# omía con (truncated)
# chada de (truncated)
# ativas y (truncated)
# ativas y (truncated)
# época en (truncated)
#  debería (truncated)
# onómicos (truncated)
# e lo que (truncated)
# bertades (truncated)
# bertades (truncated)
# Lo mismo (truncated)
# bertades (truncated)
# bertades (truncated)
# onomía y (truncated)
#  bajo el (truncated)
# os en el (truncated)
# as luces (truncated)
# anos con (truncated)
# anos con (truncated)
# la mente (truncated)
# presente (truncated)
# tigación (truncated)
#  Además, (truncated)
# ntemente (truncated)
# a por la (truncated)
# amientos (truncated)
# amientos (truncated)
# amientos (truncated)
# ía capas (truncated)
# a evitar (truncated)
# a evitar (truncated)
# a evitar (truncated)
# a evitar (truncated)
# a evitar (truncated)
# a evitar (truncated)
# a evitar (truncated)
# a evitar (truncated)
# a Chile, (truncated)
# a Chile, (truncated)
# a Chile, (truncated)
# a Chile, (truncated)
# a Chile, (truncated)
# a Chile, (truncated)
# a Chile, (truncated)
# as a las (truncated)
# as a las (truncated)
# a limpia (truncated)
#  tirasen (truncated)
# sando en (truncated)
# sando en (truncated)
# ladas es (truncated)
# aña sólo (truncated)
# aña sólo (truncated)
# están de (truncated)
# aña sólo (truncated)
# aña sólo (truncated)
# (92 años (truncated)
# suelos y (truncated)
# añosas y (truncated)
# añosas y (truncated)
# añosas y (truncated)
# añosas y (truncated)
# añosas y (truncated)
# añosas y (truncated)
# añosas y (truncated)
# añosas y (truncated)
# añosas y (truncated)
# añosas y (truncated)
# añosas y (truncated)
# añosas y (truncated)
# añosas y (truncated)
# añosas y (truncated)
#  Obrador (truncated)
#  Obrador (truncated)
#  Obrador (truncated)
#  Obrador (truncated)
#  Obrador (truncated)
#  Obrador (truncated)
#  Obrador (truncated)
#  Obrador (truncated)
#  Obrador (truncated)
#  Obrador (truncated)
#  Obrador (truncated)
#  Obrador (truncated)
#  Obrador (truncated)
# de razón (truncated)
#  Obrador (truncated)
# úmero de (truncated)
# úmero de (truncated)
# úmero de (truncated)
# atorios, (truncated)
# odar las (truncated)
#  energía (truncated)
#  empezar (truncated)
# ruptos o (truncated)
# c.** # # (truncated)
# a abuela (truncated)
# sé María (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# ruptos o (truncated)
# rinos de (truncated)
# de todos (truncated)
# de todos (truncated)
# de todos (truncated)
# de todos (truncated)
# de todos (truncated)
# de todos (truncated)
# cipar en (truncated)
# e París, (truncated)
# e París, (truncated)
# e París, (truncated)
# e París, (truncated)
# e París, (truncated)
# e París, (truncated)
# e París, (truncated)
# e París, (truncated)
# e París, (truncated)
# e París, (truncated)
# e París, (truncated)
# e París, (truncated)
# etary of (truncated)
#  100% de (truncated)
#  hay que (truncated)
# arios de (truncated)
# arios de (truncated)
# arios de (truncated)
# arios de (truncated)
# arios de (truncated)
# arios de (truncated)
# cumento. (truncated)
# etary of (truncated)
# el río y (truncated)
# el río y (truncated)
# C, en la (truncated)
# C, en la (truncated)
# C, en la (truncated)
# C, en la (truncated)
# C, en la (truncated)
# C, en la (truncated)
# C, en la (truncated)
# mbiar la (truncated)
# etary of (truncated)
# zación y (truncated)
# etary of (truncated)
# on todos (truncated)
# etary of (truncated)
# ue hacer (truncated)
# ue hacer (truncated)
# iodismo. (truncated)
# an sales (truncated)
# an sales (truncated)
# an sales (truncated)
# idad del (truncated)
# rensa el (truncated)
# veló que (truncated)
# orrecto: (truncated)
# orrecto: (truncated)
# orrecto: (truncated)
# o global (truncated)
# n ladrón (truncated)
# n ladrón (truncated)
# n ladrón (truncated)
# n ladrón (truncated)
# n ladrón (truncated)
# n ladrón (truncated)
# n ladrón (truncated)
# ricia de (truncated)
#  a nivel (truncated)
# permitió (truncated)
# a salida (truncated)
# términos (truncated)
# mana por (truncated)
# iberales (truncated)
# iberales (truncated)
# sistir a (truncated)
# iberales (truncated)
# iberales (truncated)
#  enormes (truncated)
# 2ºC será (truncated)
# pondo lo (truncated)
# 2ºC será (truncated)
# pondo lo (truncated)
# pondo lo (truncated)
# pondo lo (truncated)
# pondo lo (truncated)
# pondo lo (truncated)
# pondo lo (truncated)
# pondo lo (truncated)
#  estamos (truncated)
# pondo lo (truncated)
# daciones (truncated)
#  estamos (truncated)
# pondo lo (truncated)
#  unas 23 (truncated)
# encia de (truncated)
#  aumento (truncated)
#  estamos (truncated)
#  estamos (truncated)
#  estamos (truncated)
#  estamos (truncated)
#  estamos (truncated)
#  estamos (truncated)
#  estamos (truncated)
#  estamos (truncated)
#  estamos (truncated)
#  estamos (truncated)
#  estamos (truncated)
#  estamos (truncated)
#  estamos (truncated)
# riendo y (truncated)
# c Ivins, (truncated)
#  20 años (truncated)
# evueltos (truncated)
# evueltos (truncated)
# evueltos (truncated)
# cia, con (truncated)
# ondición (truncated)
# , por lo (truncated)
#  semilla (truncated)
# ersidad, (truncated)
# be ni en (truncated)
# ersidad, (truncated)
# ersidad, (truncated)
# sido las (truncated)
# sido las (truncated)
# sido las (truncated)
# roblemas (truncated)
#  posible (truncated)
# lógicas. (truncated)
# r fuerza (truncated)
# rabajo.* (truncated)
# es. "Así (truncated)
# es. "Así (truncated)
# es. "Así (truncated)
# ideraban (truncated)
# racasado (truncated)
# ideraban (truncated)
# anzar la (truncated)
# lógico y (truncated)
# lógico y (truncated)
# lógico y (truncated)
# lógico y (truncated)
# de 7.200 (truncated)
# de 7.200 (truncated)
# de 7.200 (truncated)
# de 7.200 (truncated)
# de 7.200 (truncated)
# de 7.200 (truncated)
# de 7.200 (truncated)
# de 7.200 (truncated)
# de 7.200 (truncated)
# de 7.200 (truncated)
# de 7.200 (truncated)
# fica con (truncated)
# fica con (truncated)
# rrestre. (truncated)
# antasma, (truncated)
# remos el (truncated)
# remos el (truncated)
# remos el (truncated)
# remos el (truncated)
# rrestre. (truncated)
# undas es (truncated)
#  cumplir (truncated)
# ncuentra (truncated)
# ncuentra (truncated)
#  cumplir (truncated)
#  cumplir (truncated)
# a que se (truncated)
# spués de (truncated)
# spués de (truncated)
# o. Si es (truncated)
# ncia que (truncated)
# omero_mx (truncated)
# omero_mx (truncated)
# omero_mx (truncated)
# omero_mx (truncated)
# ladas en (truncated)
# de todos (truncated)
# ce y las (truncated)
# s podéis (truncated)
#  su voto (truncated)
# ipio más (truncated)
# nces, el (truncated)
# RNETICA” (truncated)
# RNETICA” (truncated)
# RNETICA” (truncated)
# RNETICA” (truncated)
# RNETICA” (truncated)
# al, pero (truncated)
# ia en el (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# e fue la (truncated)
# ometió a (truncated)
# ometió a (truncated)
# ometió a (truncated)
# derados. (truncated)
# derados. (truncated)
# tura sea (truncated)
# ernandez (truncated)
# ernandez (truncated)
# ernandez (truncated)
# ernandez (truncated)
# ernandez (truncated)
# ernandez (truncated)
# ernandez (truncated)
# ernandez (truncated)
# dos esos (truncated)
# dos esos (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
# creature (truncated)
#  hicimos (truncated)
#  hicimos (truncated)
#  hicimos (truncated)
#  uno [un (truncated)
# desafíos (truncated)
# del país (truncated)
# ción), y (truncated)
# ero que, (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# ción), y (truncated)
# écada de (truncated)
#  de agua (truncated)
# ondos de (truncated)
# IO LÓPEZ (truncated)
# ue están (truncated)
# e sufren (truncated)
# ción que (truncated)
#  (compra (truncated)
#  (compra (truncated)
# Arteaga, (truncated)
# Arteaga, (truncated)
# Arteaga, (truncated)
# etta que (truncated)
# ncia del (truncated)
#  yo creo (truncated)
# ontrol y (truncated)
# tanto en (truncated)
# orque el (truncated)
# islativo (truncated)
#  yo creo (truncated)
# ntra del (truncated)
# ntra del (truncated)
# ue toman (truncated)
# ue toman (truncated)
# ue toman (truncated)
# ue toman (truncated)
# ue toman (truncated)
# ue toman (truncated)
# ue toman (truncated)
# ue toman (truncated)
# tamiento (truncated)
# decuadas (truncated)
# r Dmitry (truncated)
# alimento (truncated)
# paga sin (truncated)
# nologías (truncated)
# a que en (truncated)
# ivencia, (truncated)
# os datos (truncated)
# onómica, (truncated)
# esolverá (truncated)
# esolverá (truncated)
# esolverá (truncated)
# esolverá (truncated)
# parte de (truncated)
# contento (truncated)
# te cree, (truncated)
# te cree, (truncated)
# dades de (truncated)
#  sentido (truncated)
# a que en (truncated)
# a que en (truncated)
#  sentido (truncated)
# o amigo, (truncated)
# lo metas (truncated)
# o amigo, (truncated)
# vikingas (truncated)
# vikingas (truncated)
# vikingas (truncated)
#  el peor (truncated)
#  el peor (truncated)
#  común). (truncated)
# derar el (truncated)
#  común). (truncated)
# ados con (truncated)
# e", urge (truncated)
# iendo lo (truncated)
# orma ESG (truncated)
# tualidad (truncated)
# derar el (truncated)
# derar el (truncated)
# siglo XX (truncated)
#  . . . . (truncated)
# hombre y (truncated)
# hombre y (truncated)
# hombre y (truncated)
# hombre y (truncated)
# ue todos (truncated)
# ue todos (truncated)
# e es que (truncated)
# e es que (truncated)
# e es que (truncated)
# e es que (truncated)
# cción de (truncated)
# ro lado, (truncated)
# l PNCM a (truncated)
# os en el (truncated)
# rás cuál (truncated)
# recen la (truncated)
# Fondo de (truncated)
#  estafa. (truncated)
# lobales, (truncated)
# cimiento (truncated)
# oliberal (truncated)
# oliberal (truncated)
# oliberal (truncated)
# oliberal (truncated)
# oliberal (truncated)
# oliberal (truncated)
# oliberal (truncated)
#  fechas, (truncated)
# d Fund), (truncated)
# al norte (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# ncial de (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# d Fund), (truncated)
# ncial de (truncated)
# ncial de (truncated)
# ncial de (truncated)
# ncial de (truncated)
# utónoma. (truncated)
# medios y (truncated)
# utadores (truncated)
# hicieron (truncated)
#  no solo (truncated)
#  Habana, (truncated)
#  Habana, (truncated)
#  Habana, (truncated)
#  Habana, (truncated)
#  Habana, (truncated)
# sinados. (truncated)
# opasture (truncated)
# fícil de (truncated)
# eria, el (truncated)
# bajadora (truncated)
# gidas al (truncated)
# berá ser (truncated)
# s de los (truncated)
# s de los (truncated)
# rés para (truncated)
#  últimos (truncated)
# nadiense (truncated)
# CALYPSIS (truncated)
# acto. Es (truncated)
# insisten (truncated)
# la bilis (truncated)
#  sembrar (truncated)
#  sembrar (truncated)
#  sembrar (truncated)
#  sembrar (truncated)
# orque es (truncated)
#  mujeres (truncated)
# les , la (truncated)
# uidar el (truncated)
# vivir de (truncated)
# frente a (truncated)
#  la vida (truncated)
# parte de (truncated)
# parte de (truncated)
# parte de (truncated)
# parte de (truncated)
# itánico, (truncated)
# ¡Mago de (truncated)
# brá otra (truncated)
# ¡Mago de (truncated)
# ¡Mago de (truncated)
# p S.A.", (truncated)
# ficiente (truncated)
# debiera/ (truncated)
# gilancia (truncated)
# a agenda (truncated)
# a agenda (truncated)
# debiera/ (truncated)
# debiera/ (truncated)
# debiera/ (truncated)
# debiera/ (truncated)
# debiera/ (truncated)
# debiera/ (truncated)
# spectos. (truncated)
# yudarnos (truncated)
# yudarnos (truncated)
# as en la (truncated)
# l mundo, (truncated)
# arques y (truncated)
# r", dijo (truncated)
# r", dijo (truncated)
# r", dijo (truncated)
# r", dijo (truncated)
# r", dijo (truncated)
# r", dijo (truncated)
# r", dijo (truncated)
# r", dijo (truncated)
# r", dijo (truncated)
# r", dijo (truncated)
# r", dijo (truncated)
# r", dijo (truncated)
# las ONG, (truncated)
# rnos. Se (truncated)
# rnos. Se (truncated)
# rnos. Se (truncated)
# ismo, el (truncated)
# efraudan (truncated)
# efraudan (truncated)
# be haber (truncated)
# ladas es (truncated)
# emplo de (truncated)
# , Mali y (truncated)
# onjuntos (truncated)
# iedad de (truncated)
# iedad de (truncated)
# iedad de (truncated)
# to plazo (truncated)
# s. No se (truncated)
# ua sigan (truncated)
# acer una (truncated)
# acer una (truncated)
# acer una (truncated)
# acer una (truncated)
# acer una (truncated)
# acer una (truncated)
# acer una (truncated)
# acer una (truncated)
# acer una (truncated)
# able con (truncated)
# justicia (truncated)
# legue al (truncated)
# nversión (truncated)
#  trabajo (truncated)
# ados con (truncated)
# ción vía (truncated)
# ción vía (truncated)
# odos los (truncated)
# odos los (truncated)
#  eso. El (truncated)
# hausto y (truncated)
# l récord (truncated)
# vidad de (truncated)
# vidad de (truncated)
# vidad de (truncated)
# lado que (truncated)
# pasar el (truncated)
# tania de (truncated)
# tania de (truncated)
# riffs de (truncated)
# rosoles. (truncated)
# alizarse (truncated)
# ados con (truncated)
# la UPI ( (truncated)
# ista que (truncated)
# Retornar (truncated)
#  Lima 2. (truncated)
# restan a (truncated)
# a cantar (truncated)
# defender (truncated)
# lo demás (truncated)
# o seguir (truncated)
#  Y ahora (truncated)
# ¿Cómo se (truncated)
#  persona (truncated)
# creyendo (truncated)
# creyendo (truncated)
# a siendo (truncated)
# ntificar (truncated)
# Noruega, (truncated)
#  Tratado (truncated)
#  es a la (truncated)
# ando las (truncated)
# ando las (truncated)
# bles del (truncated)
#  de agua (truncated)
# 21 a 1.5 (truncated)
# 21 a 1.5 (truncated)
# 21 a 1.5 (truncated)
# pecies y (truncated)
#  también (truncated)
# en torno (truncated)
# aña sólo (truncated)
# entarios (truncated)
# ble. ¿Un (truncated)
# entara a (truncated)
# cipación (truncated)
# entara a (truncated)
# uaciones (truncated)
#  muertos (truncated)
#  uno [un (truncated)
# NICA DEL (truncated)
# NICA DEL (truncated)
# NICA DEL (truncated)
# NICA DEL (truncated)
# NICA DEL (truncated)
# NICA DEL (truncated)
# NICA DEL (truncated)
#  citaron (truncated)
# y premio (truncated)
# yo sobre (truncated)
# yo sobre (truncated)
#  cazar y (truncated)
# rucción, (truncated)
# rucción, (truncated)
# so lleno (truncated)
# so lleno (truncated)
# reencias (truncated)
# reencias (truncated)
# ca y sus (truncated)
# ca y sus (truncated)
#  180517” (truncated)
# engoa en (truncated)
#  180517” (truncated)
#  180517” (truncated)
#  180517” (truncated)
#  180517” (truncated)
#  180517” (truncated)
# el Golfo (truncated)
# ombeando (truncated)
# n cierta (truncated)
# stración (truncated)
# stración (truncated)
# ustancia (truncated)
# a cazada (truncated)
# ldad, la (truncated)
# ldad, la (truncated)
# diciamos (truncated)
# política (truncated)
# a pide a (truncated)
# Primeras (truncated)
# Primeras (truncated)
# Primeras (truncated)
# Primeras (truncated)
# Primeras (truncated)
# Primeras (truncated)
#  la gran (truncated)
# , llovió (truncated)
# e simple (truncated)
# conocen: (truncated)
# dadanos, (truncated)
# dadanos, (truncated)
# ue somos (truncated)
# umed are (truncated)
# umed are (truncated)
# umed are (truncated)
# umed are (truncated)
# uspender (truncated)
# tud real (truncated)
# . Ahora, (truncated)
# . Ahora, (truncated)
# ro lado, (truncated)
# sillo es (truncated)
# pse toma (truncated)
#  defensa (truncated)
#  defensa (truncated)
#  defensa (truncated)
#  defensa (truncated)
#  defensa (truncated)
#  defensa (truncated)
# ndancias (truncated)
# tigación (truncated)
# n común. (truncated)
# n común. (truncated)
# ndustria (truncated)
#  defensa (truncated)
# e élites (truncated)
# ostrado. (truncated)
#  Siempre (truncated)
#  Siempre (truncated)
# r encima (truncated)
# nuestras (truncated)
# etitivos (truncated)
#  de vida (truncated)
#  de vida (truncated)
#  También (truncated)
# n seguir (truncated)
#  También (truncated)
#  También (truncated)
# re quedó (truncated)
# re quedó (truncated)
#  isla se (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# , cuando (truncated)
# , cuando (truncated)
# , cuando (truncated)
# , cuando (truncated)
# e al que (truncated)
# ropician (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
# e al que (truncated)
#  ser más (truncated)
#  ser más (truncated)
#  grandes (truncated)
# iones en (truncated)
# a de los (truncated)
# a de los (truncated)
# a de los (truncated)
# a de los (truncated)
# amos ver (truncated)
# yoría de (truncated)
# diciamos (truncated)
#  está en (truncated)
#  está en (truncated)
#  está en (truncated)
#  está en (truncated)
#  está en (truncated)
#  malvado (truncated)
# a que la (truncated)
#  (compra (truncated)
#  (compra (truncated)
# e debían (truncated)
# . 10. No (truncated)
# ntas con (truncated)
# ntas con (truncated)
# a contra (truncated)
# debrandt (truncated)
# atalidad (truncated)
# do, cada (truncated)
# ar junto (truncated)
#  Se verá (truncated)
# o pasado (truncated)
# crédito, (truncated)
# timiento (truncated)
# iones de (truncated)
# aña sólo (truncated)
# aña sólo (truncated)
# aña sólo (truncated)
# aña sólo (truncated)
# 1880, el (truncated)
#  poder y (truncated)
#  poder y (truncated)
# do el sexo infantil.
# ible que (truncated)
# do el sexo infantil.
# torio de (truncated)
# aliza el (truncated)
# ienza en (truncated)
# ame será (truncated)
#  quieren (truncated)
# a que la (truncated)
# casez de (truncated)
# iamiento (truncated)
# mejanza" (truncated)
# cangrejo (truncated)
# n el que (truncated)
# s entero (truncated)
# s entero (truncated)
# portamos (truncated)
# aña sólo (truncated)
# aña sólo (truncated)
# reyente, (truncated)
# aña sólo (truncated)
# aña sólo (truncated)
# aña sólo (truncated)
# aña sólo (truncated)
# aña sólo (truncated)
# aña sólo (truncated)
# aña sólo (truncated)
# o de sus (truncated)
# e se han (truncated)
# er dicho (truncated)
# er dicho (truncated)
# riben la (truncated)
# te Trump (truncated)
# e es que (truncated)
# no llega (truncated)
#  muertes (truncated)
# aña sólo (truncated)
# ter Kike (truncated)
# ter Kike (truncated)
# ter Kike (truncated)
# ter Kike (truncated)
# ter Kike (truncated)
#  Uranio, (truncated)
# ente. Lo (truncated)
# nte. Las (truncated)
# lones de (truncated)
# s por el (truncated)
# hombres, (truncated)
#  visitan (truncated)
# ente por (truncated)
# aña sólo (truncated)
# calentar (truncated)
# ido, qué (truncated)
# sado. El (truncated)
# otorgado (truncated)
# otorgado (truncated)
# ue todos (truncated)
# uros por (truncated)
# uerdo de (truncated)
# uerdo de (truncated)
#  como la (truncated)
#  como la (truncated)
#  como la (truncated)
#  como la (truncated)
# itir co2 (truncated)
# itir co2 (truncated)
# itir co2 (truncated)
# aña sólo (truncated)
# tamiento (truncated)
# tamiento (truncated)
# otivo de (truncated)
# uando se (truncated)
# omienzo. (truncated)
# anías se (truncated)
# aña sólo (truncated)
# osteros. (truncated)
# a de hoz (truncated)
# aña sólo (truncated)
# aña sólo (truncated)
# . Minesa (truncated)
#  las 100 (truncated)
# ersible" (truncated)
# ersible" (truncated)
# ersible" (truncated)
# ersible" (truncated)
# el 13 de (truncated)
#  445.568 (truncated)
# pos eran (truncated)
# pos eran (truncated)
# pos eran (truncated)
# ientales (truncated)
# re ellos (truncated)
#  vez que (truncated)
# , y tras (truncated)
# sa es la (truncated)
# sa es la (truncated)
# sa es la (truncated)
# sa es la (truncated)
# smo para (truncated)
# smo para (truncated)
# smo para (truncated)
# smo para (truncated)
# sa es la (truncated)
# sa es la (truncated)
# sa es la (truncated)
# sa es la (truncated)
# sa es la (truncated)
# sa es la (truncated)
# obre los (truncated)
# ecuestro (truncated)
# an en la (truncated)
# ir a sus (truncated)
# estar de (truncated)
# estar de (truncated)
# estar de (truncated)
# guerras, (truncated)
# guerras, (truncated)
# STUDIOS: (truncated)
# STUDIOS: (truncated)
# STUDIOS: (truncated)
# STUDIOS: (truncated)
# STUDIOS: (truncated)
# STUDIOS: (truncated)
# STUDIOS: (truncated)
# STUDIOS: (truncated)
# STUDIOS: (truncated)
# reses de (truncated)
# mente un (truncated)
# práctica (truncated)
# práctica (truncated)
# práctica (truncated)
# inalidad (truncated)
#  ecocida (truncated)
# norte de (truncated)
# epública (truncated)
# práctica (truncated)
# ladas es (truncated)
# é opina? (truncated)
# toration (truncated)
# PROTECT, (truncated)
# PROTECT, (truncated)
# PROTECT, (truncated)
# PROTECT, (truncated)
# PROTECT, (truncated)
# PROTECT, (truncated)
# PROTECT, (truncated)
# PROTECT, (truncated)
# raño. La (truncated)
#  no será (truncated)
# PERDÓN A (truncated)
# PERDÓN A (truncated)
# PERDÓN A (truncated)
# PERDÓN A (truncated)
# PERDÓN A (truncated)
# PERDÓN A (truncated)
# PERDÓN A (truncated)
# PERDÓN A (truncated)
# ensurado (truncated)
# ensurado (truncated)
# ensurado (truncated)
# ensurado (truncated)
# ensurado (truncated)
# PERDÓN A (truncated)
# tante no (truncated)
# PERDÓN A (truncated)
# PERDÓN A (truncated)
# PERDÓN A (truncated)
# PERDÓN A (truncated)
# tante no (truncated)
# erecho a (truncated)
# l mínimo (truncated)
# CIMIENTO (truncated)
# CIMIENTO (truncated)
# CIMIENTO (truncated)
# CIMIENTO (truncated)
# CIMIENTO (truncated)
# CIMIENTO (truncated)
# CIMIENTO (truncated)
# CIMIENTO (truncated)
# riamente (truncated)
# omesa de (truncated)
# o CAMBIO (truncated)
# o y otro (truncated)
# o y otro (truncated)
# o CAMBIO (truncated)
# l cáncer (truncated)
# o CAMBIO (truncated)
#  2019 en (truncated)
#  2019 en (truncated)
#  2019 en (truncated)
#  2019 en (truncated)
#  2019 en (truncated)
#  2019 en (truncated)
#  Después (truncated)
# ausfeld, (truncated)
# ausfeld, (truncated)
# ausfeld, (truncated)
# ausfeld, (truncated)
# ausfeld, (truncated)
# ausfeld, (truncated)
# perarían (truncated)
# perarían (truncated)
# vimiento (truncated)
# recen de (truncated)
# e mató a (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# avés del (truncated)
# jetivos, (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# relativa (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
# ad hacia (truncated)
#  altura. (truncated)
# eras. Es (truncated)
# a contra (truncated)
# ahogados (truncated)
# uras que (truncated)
#  plantas (truncated)
# rente de (truncated)
# en Asia. (truncated)
# en Asia. (truncated)
# en Asia. (truncated)
# en Asia. (truncated)
# lido con (truncated)
# lrededor (truncated)
# , que ha (truncated)
# presenta (truncated)
# tica más (truncated)
# ESENTADO (truncated)
# iere que (truncated)
# dad, por (truncated)
# elantado (truncated)
# á valido (truncated)
# cionales (truncated)
# nculpado (truncated)
# nculpado (truncated)
# udiados. (truncated)
# énico- y (truncated)
# r nuevas (truncated)
#  10 o 20 (truncated)
# planeta, (truncated)
# al todas (truncated)
# al todas (truncated)
#  tenia y (truncated)
#  todo lo (truncated)
# cisiones (truncated)
# zado una (truncated)
# zado una (truncated)
# zado una (truncated)
# getación (truncated)
# general. (truncated)
# ideraban (truncated)
# ideraban (truncated)
# res, una (truncated)
# res, una (truncated)
#  autores (truncated)
# ianza en (truncated)
# terminar (truncated)
# gunos de (truncated)
#  «Pollin (truncated)
# rando en (truncated)
# as malas (truncated)
# a que no (truncated)
# eseable, (truncated)
# minución (truncated)
#  AMPs la (truncated)
# inicano, (truncated)
# solo hay (truncated)
# s de los (truncated)
# del cual (truncated)
# del cual (truncated)
#  energía (truncated)
# según el (truncated)
# según el (truncated)
# e el oso (truncated)
#  revivir (truncated)
# o Puerto (truncated)
# an sobre (truncated)
# NUESTROS (truncated)
# NUESTROS (truncated)
# s áspero (truncated)
# y fauna. (truncated)
# ra en el (truncated)
#  algunos (truncated)
# ico para (truncated)
# prevenir (truncated)
# prevenir (truncated)
# ercio de (truncated)
# s aguas. (truncated)
#  25 años (truncated)
# 1988 con (truncated)
# ilvia G. (truncated)
# ión para (truncated)
# ión para (truncated)
# ión para (truncated)
# Báltico. (truncated)
# hat ¡POR (truncated)
# hat ¡POR (truncated)
# tros con (truncated)
# tros con (truncated)
# tros con (truncated)
# tros con (truncated)
# tros con (truncated)
# tros con (truncated)
# tros con (truncated)
# tros con (truncated)
# tros con (truncated)
# tros con (truncated)
# tros con (truncated)
# tros con (truncated)
# tros con (truncated)
# tros con (truncated)
# feras de (truncated)
# e tiempo (truncated)
# plástica (truncated)
# o con 20 (truncated)
# o con 20 (truncated)
#  bosques (truncated)
# s noches (truncated)
# s noches (truncated)
# SCUENTOS (truncated)
# SCUENTOS (truncated)
# que está (truncated)
#  asumido (truncated)
# res, más (truncated)
# recupera (truncated)
#  la roca (truncated)
# personas (truncated)
# de fuego (truncated)
# de fuego (truncated)
# de fuego (truncated)
#  tenemos (truncated)
#  asuntos (truncated)
# cuáticas (truncated)
# mbiente, (truncated)
# a de las (truncated)
# e avance (truncated)
#  cabo Mi (truncated)
# caída de (truncated)
# caída de (truncated)
# caída de (truncated)
# caída de (truncated)
# entrismo (truncated)
# humano y (truncated)
# a, estas (truncated)
# resto de (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# a, estas (truncated)
# itler no (truncated)
# itler no (truncated)
# itler no (truncated)
# itler no (truncated)
# o por la (truncated)
#  2.5 mil (truncated)
#  2.5 mil (truncated)
# erficial (truncated)
# ones” de (truncated)
# ones” de (truncated)
# al de la (truncated)
# rtalezas (truncated)
# el marco (truncated)
# itido en (truncated)
# restales (truncated)
# vikingas (truncated)
# chaba su (truncated)
# inauguró (truncated)
# sobre el (truncated)
# el sitio (truncated)
# ó un 2%, (truncated)
# ó un 2%, (truncated)
# sórdenes (truncated)
# na nueva (truncated)
# na nueva (truncated)
# rensa de (truncated)
# rensa de (truncated)
#  así que (truncated)
# ltiples, (truncated)
# morizado (truncated)
# ltiples, (truncated)
# ltiples, (truncated)
# ltiples, (truncated)
# ltiples, (truncated)
#  podrían (truncated)
#  podrían (truncated)
#  podrían (truncated)
#  podrían (truncated)
# ias para (truncated)
#  ley del (truncated)
# e Pando. (truncated)
# e Pando. (truncated)
# teros en (truncated)
# ntera en (truncated)
# aguar, y (truncated)
# no local (truncated)
# de humo, (truncated)
# vencidas (truncated)
# er. Pero (truncated)
# o Ramos, (truncated)
# or. Port (truncated)
# ustible. (truncated)
# igadores (truncated)
# e Nasser (truncated)
#  global, (truncated)
# r con el (truncated)
# r con el (truncated)
# r con el (truncated)
# r con el (truncated)
# r con el (truncated)
# r con el (truncated)
# entarios (truncated)
# bulario, (truncated)
# ciones y (truncated)
# a llevar (truncated)
# tiene un (truncated)
# agas una (truncated)
# bulario, (truncated)
# des para (truncated)
# er. Pero (truncated)
# er. Pero (truncated)
# er. Pero (truncated)
# er. Pero (truncated)
# er. Pero (truncated)
# er. Pero (truncated)
# er. Pero (truncated)
# er. Pero (truncated)
# er. Pero (truncated)
# o básico (truncated)

# %% [markdown]
# Seems that facebook messages/publications are truncated to $4,999$ characters!

# %%
df_clean['messageWords_length'].plot(bins=100, kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## N-grams

# %% [markdown]
# ### Uni-gram

# %% [markdown]
# #### Raw

# %% [markdown]
# First, let's analyze text from **raw** (without any changes)

# %%
corpus = get_corpus_N_gram(list_text=df_clean['Message'], stop_words=None, ngram=1, show_plot=True)
# Out:
# Length of corpus: 43230575

# %% [markdown]
# Those are meaningless words, all of them (and similar) will be added to **stopwords**, so they won't be use for future analysis.

# %% [markdown]
# #### With stop-words

# %%
with open(r'..\..\utils\spanish_stopwords.txt', 'r') as archivo:
    stop_words = [linea.strip() for linea in archivo]
len(stop_words)
# Out:
# 608

# %%
stop_words[:10]
# Out:
# ['a',
#  'actualmente',
#  'adelante',
#  'además',
#  'afirmó',
#  'agregó',
#  'ahora',
#  'ahí',
#  'al',
#  'algo']

# %%
corpus = get_corpus_N_gram(list_text=df_clean['Message'], stop_words=stop_words, ngram=1, show_plot=True)
# Out:
# Length of corpus: 23964982

# %% [markdown]
# - Upper/Lower-case must be removed, so that "*Cambio*" and "*cambio*" are counted in the same word.
# - It is suggested by the autor to remove accents
# - No include punctiations signs: **, ; . : '**
# - No include URLs inside text

# %% [markdown]
# #### Stop-words, text to lowercase, no URLs: clean text

# %%
df_clean['Message_clean'] = df_clean['Message'].apply(lambda x: clean_text(x))

# %%
corpus = get_corpus_N_gram(list_text=df_clean['Message_clean'], stop_words=stop_words, ngram=1, show_plot=True)
# Out:
# Length of corpus: 21427211

# %% [markdown]
# ### Bi-gram

# %%
corpus = get_corpus_N_gram(list_text=df_clean['Message_clean'], stop_words=stop_words, ngram=2, show_plot=True)
# Out:
# Length of corpus: 21141186

# %% [markdown]
# ### Tri-gram

# %%
corpus = get_corpus_N_gram(df_clean['Message_clean'], stop_words=stop_words, ngram=3, show_plot=True)
# Out:
# Length of corpus: 20861112

# %%
df_clean.to_pickle(r'..\..\..\data\preprocessed\clean_text_fb_groups_nanook.pkl')
